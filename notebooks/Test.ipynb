# %%
import numpy as np
#import tensorflow as tf
from utility import *
import matplotlib.pyplot as plt
from matplotlib import colors
import os
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
a = np.load('mit_low_res.npy')

# %%
small_part = a[:500, :500]
showImages([small_part])
# Out:
# Number of rows and columns: 1, 1

# %%
max_value = 10000
for i in range(len(small_part)-1):
    if small_part[i, i+1] != 0:
        small_part[i, i+1:] = (small_part[i, i+1:] / small_part[i, i+1]) * max_value
        small_part[i+1:, i] = (small_part[i+1:, i] / small_part[i+1, i]) * max_value
    #small_part[i, i] = 0
for i in range(1, len(small_part)-1):
    print(small_part[i, i], small_part[i, i+1], small_part[i, i-1])
# Out:
# (346.0, 10000.0, 0.0)
# (42.0, 10000.0, 10000.0)
# (70.0, 10000.0, 10000.0)
# (32.0, 10000.0, 10000.0)
# (54.0, 0.0, 10000.0)
# (36.0, 10000.0, 0.0)
# (66.0, 10000.0, 10000.0)
# (98.0, 10000.0, 10000.0)
# (156.0, 10000.0, 10000.0)
# (166.0, 10000.0, 10000.0)
# (104.0, 10000.0, 10000.0)
# (58.0, 10000.0, 10000.0)
# (182.0, 10000.0, 10000.0)
# (128.0, 10000.0, 10000.0)
# (132.0, 10000.0, 10000.0)
# (186.0, 10000.0, 10000.0)
# (294.0, 10000.0, 10000.0)
# (60.0, 10000.0, 10000.0)
# (108.0, 10000.0, 10000.0)
# (194.0, 10000.0, 10000.0)
# (60.0, 10000.0, 10000.0)
# (104.0, 10000.0, 10000.0)
# (76.0, 10000.0, 10000.0)
# (192.0, 10000.0, 10000.0)
# (102.0, 10000.0, 10000.0)
# (68.0, 10000.0, 10000.0)
# (140.0, 10000.0, 10000.0)
# (198.0, 10000.0, 10000.0)
# (216.0, 10000.0, 10000.0)
# (94.0, 10000.0, 10000.0)
# (152.0, 10000.0, 10000.0)
# (112.0, 10000.0, 10000.0)
# (214.0, 10000.0, 10000.0)
# (112.0, 10000.0, 10000.0)
# (46.0, 10000.0, 10000.0)
# (114.0, 10000.0, 10000.0)
# ...

# %%
showImages([small_part])
# Out:
# Number of rows and columns: 1, 1
