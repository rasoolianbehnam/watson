# %% [markdown]
# # Graphlet Correlation Analysis
#
# Remember, in notebook *Thresholding*, I thresholded contact maps and saved so that
# orca can read them.
#
# In this notebook, I perform two actions:
# 1. I apply `count5` procedure in orca to extract 73 orbits for each loci in each
# chromosome. After this stage, graphlets will be save with `.graphlets` extension
# in the `./data` folder.
#
# 2. I then read the graphlets and find both loci-wise distance
# and graphlet-wise correlations
# between the four cell lines.
#
# By repeating steps 1 and 2 for all 23 chromosomes, I will have pairwise MIC values for all
# orbits of all cell lines. I would eventually be able to have a data array of shape
# ``` A(23 * 73) ```, for each pair of cell lines where `A[i, j]` denotes the correlation
# between the jth orbit in the ith chromosome.

# %%
import numpy as np
import cv2
from library.utility import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
#from iced import normalization
#from iced import filter
import subprocess
from scipy.interpolate import spline
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/bzr0014/envs/watson/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['colors', 'log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
chr2index= {}
index2chr = {}
count = 0
for chr1 in range(1, 24):
    for chr2 in range(chr1, 24):
        chr2index[(chr1, chr2)] = count
        index2chr[count] = (chr1, chr2)
        count += 1
        
inter_indices = []
for chr1 in range(1, 24):
    inter_indices.append(chr2index[(chr1, chr1)])
#print("Same indices: %s\n"%sameIndices)
intra_indices = []
for chr1 in range(1, 24):
    for chr2 in range(chr1+1, 24):
        intra_indices.append(chr2index[(chr1, chr2)])
#print("Different indices: %s"%differentIndices)

# %%
data_names = ["MIT", "ALL", "RL", "CALL4"]
root = ".."
file_dir_template = "%s/extracted_all_contact_%s"%(root,"%s")
file_name_template = "%s/all_in_one_500kb.npy"%(file_dir_template)
print("File Directory: \"%s\""%file_dir_template)
print("File Name Template: \"%s\""%file_name_template)

mit_colors = ['#0d75f8', '#42b395', '#99cc04']
cancer_colors = ['#ab1239', '#c83cb9', '#cf524e']
# Out:
# File Directory: "../extracted_all_contact_%s"
# File Name Template: "../extracted_all_contact_%s/all_in_one_500kb.npy"

# %% [markdown]
# ## Extracting orbits from thresholded files

# %%
# Uncommenct the following code to extract graphlets from contact maps
#for chr1 in range(1, 23):
#    for chr2 in range(chr1, 23):
#        command = 'Rscript ../external/rscript_intra.r %s %s'%(chr1, chr2)
#        output = subprocess.check_output(command, subprocess.STDOUT, shell=True)
#        print(output)

# %% [markdown]
# ## Reading Already saved orbits

# %%
graphlets = {}
for cell in data_names:
    graphlets[cell] = {}
    count = 0
    for chr1 in range(1, 24):
        graphlets[cell][chr1] = {}
        for chr2 in range(chr1, 24):
            graphlets[cell][chr1][chr2] = readMat\
            ("%s/data/graphlets/chr%02d_chr%02d_%s.graphlets"%(root, chr1, chr2, cell.lower()), delimiter=" ").astype('uint32') 
            count += 1

# %% [markdown]
# ## Putting extracted graphlets in order
# The following code block assembles all 23 orbit signature vectors of a loci into a $23 \times 73$ matrix.

# %%
lengths = {}
for key in data_names:
    print(key)
    lengths[key] = np.load("../data/contact_maps/length_low_res.npy")

num_loci = 100000
loci_data = {}
for cell1 in data_names:
    loci_data[cell1] = {}
    num_loci = int(np.min([np.sum(lengths[cell1][-1]), num_loci]))
    print num_loci
    for l in range(num_loci+1):
        loci_data[cell1][l] = np.zeros((24, 73), dtype='uint32')

for cell1 in data_names:
    for chr1 in range(1, 24):
        for chr2 in range(chr1, 24):
            l1 = lengths[cell1][chr1, :]
            l2 = lengths[cell1][chr2, :]
            temp = graphlets[cell1][chr1][chr2]
            if chr1 == chr2:
                for l in range(len(temp)):
                    loci_abs_num = l1[0] + l
                    loci_data[cell1][loci_abs_num][chr1] = temp[l]                
            else:
                for l in range(l1[1]):
                    loci_abs_num = l1[0] + l
                    loci_data[cell1][loci_abs_num][chr2] = temp[l]                
                for l in range(l1[1], len(temp)):
                    loci_abs_num = l2[0] + l - l1[1]
                    loci_data[cell1][loci_abs_num][chr1] = temp[l]
# Out:
# MIT
# ALL
# RL
# CALL4
# 6053
# 6053
# 6053
# 6053

# %%
# Test of the above procedure, the absolute difference should be 0
sum_diffs = 0
for cell_index in np.random.randint(0, len(data_names), size=3):
    cell = data_names[cell_index]
    for chr1 in np.random.choice(range(1, 24), size=3):
        for chr2 in np.random.choice(range(1, 24), size=3):
            i = np.argmin([chr1, chr2])
            if i == 1:
                c1 = chr2
                c2 = chr1
            else:
                c1 = chr1
                c2 = chr2
            for loci in np.random.choice(range(lengths[cell][c1, 1]), size=3):
                sum_diffs += int(np.sum(np.abs(loci_data[cell][loci + lengths[cell][c1, 0]][c2] - graphlets[cell][c1][c2][loci])))
print("Absolute Diference: %d"%(sum_diffs))
print len(loci_data['MIT'])
# Out:
# Absolute Diference: 0
# 6054

# %%
## Saving files
#for cell in data_names:
#    for loci in range(num_loci):
#            file_name = "data/%s_loci%d"%(cell, loci)
#            print(file_name)
#            np.save(file_name, loci_data[cell][loci])

# %% [markdown]
# ## Calculating Loci-wise distances:
# Now we can compare contact maps with each other based on
# the *signature distance* measure. For each contact map
# and each pair of cells, we can perform a t-test on
# the signature distances in order to see whether the
# differences are 0 or not. In the following code
# blocks, first we calculate the signature distances
# between each pair of cells and then some visualizaitons
# demonstrate how cells are different.

# %%
chr2count = {}
count2chr = {}
count = 0
for chr1 in range(1, 24):
    for chr2 in range(chr1, 24):
        chr2count[(chr1, chr2)] = count
        count2chr[count] = (chr1, chr2)
        count += 1
        
cells = ['mit', 'all', 'rl', 'call4']
graphlets = {}
for cell in cells:
    graphlets[cell] = {}
    for chr1 in range(1, 24):
        graphlets[cell][chr1] = {}
        for chr2 in range(chr1, 24):
            graphlets[cell][chr1][chr2] = readMat\
            ("%s/data/graphlets/chr%02d_chr%02d_%s.graphlets"%\
             (root, chr1, chr2, cell), delimiter=" ").astype('uint32') 
        
distances = {}
actual_distances = {}
for cell in cells:
    distances[cell] = {}
    actual_distances[cell] = {}
    
for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue
        distances[cell1][cell2] = np.zeros((count, 4))
        distances[cell2][cell1] = distances[cell1][cell2]
        actual_distances[cell1][cell2] = [None] * (count)
        actual_distances[cell2][cell1] = actual_distances[cell1][cell2]
        #cell (i, j) will store correlation between orbital j in 
        #ith chromosome
        

for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue
        print(cell1, cell2)
        for chr1 in range(1, 24):
            for chr2 in range(chr1, 24):
                count = chr2count[(chr1, chr2)]
                temp =  row_wise_graphlet_distance(graphlets[cell1][chr1][chr2]\
                                , graphlets[cell2][chr1][chr2])
                actual_distances[cell1][cell2][count] = temp
                distances[cell1][cell2][count, 0] = np.nanmean(temp)
                distances[cell1][cell2][count, 1] = np.nanstd(temp, ddof=1)
                t0, pvalue = t_test(temp, one_sided=True)
                distances[cell1][cell2][count, 2] = t0
                distances[cell1][cell2][count, 3] = pvalue
# Out:
# ('mit', 'rl')
# ('all', 'mit')
# ('all', 'rl')
# ('all', 'call4')
# ('call4', 'mit')
# ('call4', 'rl')

# %% [markdown]
# ### All pair-wise signature distances
# The following is a graph comparing contact maps in terms of average loci-loci distances. For each pair of cells
# $A$ and $B$, $\bar{d}^{\hspace{.2cm}A,B}_{ij}$ is calculated. As can be seen in the third graph, which also shows
# errors of half standard deviation, we can see that almost none
# of the graphlet distances are not within half a standard
# deviation of zero.

# %%
pylab.rcParams['figure.figsize'] = (200, 90)
myIndices = []
chr1 = 14
for chr2 in range(1, 24):
    if chr1 < chr2:
        myIndices.append(chr2count[(chr1, chr2)])
    else:
        myIndices.append(chr2count[(chr2, chr1)])
pylab.rcParams['figure.figsize'] = (25, 9)
mit_count = cancer_count = 0
x = range(len(distances['mit']['rl']))
ax = plt.subplot(1, 1, 1)
for cell1 in distances:
    for cell2 in distances[cell1]:
        if cell1 >= cell2:
            continue
        y = distances[cell1][cell2][myIndices, 0]
        x = np.arange(len(y))+1
        xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
        y_smooth = spline(x, y,xnew)
        ax.scatter(x, y)
        if cell1 == 'mit' or cell2 == 'mit':
            color = mit_colors[mit_count]
            mit_count += 1
        else:
            color = cancer_colors[cancer_count]        
            cancer_count += 1
        ax.plot(xnew, y_smooth, marker=" ", label="%s vs %s"%(cell1.upper(), cell2.upper())\
                , linewidth=4,  alpha=.5, color=color)       
        #ax.plot(x, y, marker=".", label="%s vs %s"%(cell1, cell2))
        ax.set_ylim([0, 1.5])
        ax.set_ylabel('Average loci-loci distance', fontsize=20)
        ax.set_xlabel('Contact maps of chromosome %d'%(chr1), fontsize=20)
        ax.set_xticks(x)

plt.legend(prop={'size':12})
plt.show()
# Out:
# /home/bzr0014/envs/watson/lib/python2.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %% [markdown]
# # MIC Analysis

# %%
header = "MIT,ALL,RL,CALL4"
for chr1 in range(1, 24):
    for chr2 in range(chr1, 24):
        for orbit in range(0, 73):
            filename = "%s/data/orbits/chr%02d_chr%02d_orbit%02d.csv"%(root, chr1, chr2, orbit)
            n = 100000000
            for cell in data_names:
                cell = cell.upper()
                n = np.min([graphlets[cell.lower()][chr1][chr2][:, orbit].shape[0], n])
            temp = np.zeros((n, len(data_names)))
            count = 0
            for cell in data_names:
                temp[:, count] = graphlets[cell.lower()][chr1][chr2][:n, orbit]
                count += 1
            np.savetxt(filename, temp, delimiter=',', header=header)

# %%
#for chr1 in range(1, 24):
#    for chr2 in range(chr1, 24):
#        for orbit in range(73):
#            file_name = "data/chr%02d_chr%02d_orbit%02d.csv"%(chr1, chr2, orbit)
#            command = "java -jar mine.jar %s -allPairs"%file_name
#            print(command)
#            os.system(command)

# %%
cells = ['mit', 'all', 'rl', 'call4']
chr2count = {}
count2chr = {}
count = 0
for chr1 in range(1, 24):
    for chr2 in range(chr1, 24):
        chr2count[(chr1, chr2)] = count
        count2chr[count] = (chr1, chr2)
        count += 1
        
mics = {}
for cell in cells:
    mics[cell] = {}
    
for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue
        mics[cell1][cell2] = np.zeros((count, 73))
        mics[cell2][cell1] = mics[cell1][cell2]
        #cell (i, j) will store correlation between orbital j in 
        #ith chromosome
        
#for cell1 in cells:
#    for cell2 in cells:
#        if cell2 <= cell1:
#            continue
#        print(cell1, cell2)
#        count = 0 
#        for chr1 in range(1, 24):
#            for chr2 in range(chr1, 24):
#                mics[cell1][cell2][count, :] =  row_wise_pearson(graphlets[cell1][chr1][chr2].T\
#                                , graphlets[cell2][chr1][chr2].T)
#                count+=1
import string
for chr1 in range(1, 24):
    for chr2 in range(chr1, 24):
        for orbit in range(73):
            filename = "../data/mics/chr%02d_chr%02d_orbit%02d.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"\
            %(chr1, chr2, orbit)
            print(filename)
            csvfile = open(filename, 'r')
            csvfile.readline()
            for line in csvfile:
                splitted = line.split(',')
                a = string.replace(splitted[0], "# ", "").lower()
                b = string.replace(splitted[1], "# ", "").lower()
                c = float(splitted[2])
                #print(a, b, c)
                mics[a][b][chr2count[(chr1, chr2)], orbit] = c
# Out:
# ../data/mics/chr01_chr01_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr01_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr02_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr03_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr04_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr05_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr06_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr07_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr08_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr01_chr09_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ...
# ../data/mics/chr22_chr22_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr22_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr22_chr23_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit00.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit01.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit02.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit03.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit04.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit05.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit06.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit07.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit08.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit09.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit10.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit11.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit12.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit13.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit14.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit15.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit16.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit17.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit18.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit19.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit20.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit21.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit22.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit23.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit24.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit25.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit26.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit27.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit28.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit29.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit30.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit31.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit32.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit33.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit34.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit35.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit36.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit37.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit38.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit39.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit40.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit41.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit42.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit43.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit44.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit45.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit46.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit47.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit48.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit49.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit50.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit51.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit52.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit53.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit54.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit55.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit56.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit57.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit58.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit59.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit60.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit61.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit62.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit63.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit64.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit65.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit66.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit67.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit68.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit69.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit70.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit71.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# ../data/mics/chr23_chr23_orbit72.csv,allpairs,cv=0.0,B=n^0.6,Results.csv

# %%
numPairs = 0
cellPair2num = {}
for cell1 in mics:
    cellPair2num[cell1] = {}
    for cell2 in mics[cell1]:
        if cell1 <= cell2:
            continue
        cellPair2num[cell1][cell2] = numPairs
        numPairs += 1
vectorMic = np.zeros((numPairs, count, 73))
print(vectorMic.shape)
pairCount = 0
for cell1 in mics:
    for cell2 in mics[cell1]:
        if cell1 <= cell2:
            continue        
        vectorMic[pairCount] = mics[cell1][cell2]
        pairCount += 1
print(numPairs)
# Out:
# (6, 276, 73)
# 6

# %%
sameIndices = []
for chr1 in range(1, 24):
    sameIndices.append(chr2count[(chr1, chr1)])
#print("Same indices: %s\n"%sameIndices)
differentIndices = []
for chr1 in range(1, 24):
    for chr2 in range(chr1+1, 24):
        differentIndices.append(chr2count[(chr1, chr2)])
#print("Different indices: %s\n"%differentIndices)

indices = np.array([ 0,  1,  2,  4,  5,  6,  7,  8, 15, 16, 17, 18, 19, 20, 21, 22, 23,
        35, 36, 37, 38, 49, 50]) 
nonIndices = []
for i in range(73):
    if i not in indices:
        nonIndices.append(i)

#print("Indices: %s\n"%indices)
#print("Non-indices: %s"%nonIndices)

# %%
pylab.rcParams['figure.figsize'] = (200, 90)
custIndices = []
chr1 = 14
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
print(mics['mit']['rl'].shape)
pylab.rcParams['figure.figsize'] = (25, 9)
x = range(len(mics['mit']['rl']))
ax = plt.subplot(1, 1, 1)
cancer_count = mit_count = 0
for cell1 in cellPair2num:
    for cell in cellPair2num[cell1]:
        tmp = vectorMic - np.mean(vectorMic, axis=(0, 2), keepdims=True)
        y = np.nanmean(tmp[cellPair2num[cell1][cell]][:, :][:, indices], axis=1) 
        
        x = np.array(range(len(y))) + 1
        xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
        y_smooth = spline(x, y,xnew)
        if cell1 == 'mit' or cell == 'mit':
            color = mit_colors[mit_count]
            mit_count += 1
        else:
            color = cancer_colors[cancer_count]
            cancer_count += 1
        ax.scatter(x, y, color=color)
        ax.plot(xnew, y_smooth, marker=" ", label="%s vs %s"%(cell1.upper(), cell.upper())\
                , linewidth=4, alpha=.5, color=color)
        ax.set_ylim([-1, 1])
        ax.set_xlabel("Contact Maps of Chromosome %d"%(chr1), fontsize=25)
        ax.set_ylabel("Average MIC", fontsize=25)
        #ax.set_xticks(x)
plt.legend(prop={'size':15})
plt.show()
# Out:
# (276, 73)
# /home/bzr0014/git/watson/virt/lib/python2.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
pylab.rcParams['figure.figsize'] = (200, 90)
custIndices = []
chr1 = 14
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
print(mics['mit']['rl'].shape)
pylab.rcParams['figure.figsize'] = (25, 9)
x = range(len(mics['mit']['rl']))
ax = plt.subplot(1, 1, 1)
cancer_count = mit_count = 0
for cell1 in cellPair2num:
    for cell in cellPair2num[cell1]:
        tmp = vectorMic - np.mean(vectorMic, axis=(0, 2), keepdims=True)
        y = np.nanmean(tmp[cellPair2num[cell1][cell]][:, :][:, :], axis=1) 
        
        x = np.array(range(len(y))) + 1
        xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
        y_smooth = spline(x, y,xnew)
        if cell1 == 'mit' or cell == 'mit':
            color = mit_colors[mit_count]
            mit_count += 1
        else:
            color = cancer_colors[cancer_count]
            cancer_count += 1
        ax.scatter(x, y, color=color)
        ax.plot(xnew, y_smooth, marker=" ", label="%s vs %s"%(cell1.upper(), cell.upper())\
                , linewidth=4, alpha=.5, color=color)
        ax.set_ylim([-1, 1])
        ax.set_xlabel("Contact Maps of Chromosome %d"%(chr1), fontsize=25)
        ax.set_ylabel("Average MIC", fontsize=25)
        ax.set_xticks(x)
plt.legend(prop={'size':15})
plt.show()
# Out:
# (276, 73)
# /home/bzr0014/git/watson/virt/lib/python2.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
pylab.rcParams['figure.figsize'] = (200, 90)
custIndices = []
chr1 = 14
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
print(mics['mit']['rl'].shape)
pylab.rcParams['figure.figsize'] = (25, 9)
x = range(len(mics['mit']['rl']))
ax = plt.subplot(1, 1, 1)
cancer_count = mit_count = 0
for cell1 in mics:
    for cell in mics[cell1]:
        if cell < cell1:
            continue
        y = np.nanmean(mics[cell1][cell][custIndices, :][:, indices], axis=1)
        x = np.array(range(len(y))) + 1
        xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
        y_smooth = spline(x, y,xnew)
        if cell1 == 'mit' or cell == 'mit':
            color = mit_colors[mit_count]
            mit_count += 1
        else:
            color = cancer_colors[cancer_count]
            cancer_count += 1
        ax.scatter(x, y, color=color)
        ax.plot(xnew, y_smooth, marker=" ", label="%s vs %s"%(cell1.upper(), cell.upper())\
                , linewidth=4, alpha=.5, color=color)
        ax.set_ylim([0, 1])
        ax.set_xlabel("Contact Maps of Chromosome %d"%(chr1), fontsize=25)
        ax.set_ylabel("Average MIC", fontsize=25)
        ax.set_xticks(x)
plt.legend(prop={'size':15})
plt.show()
# Out:
# (276, 73)
# /home/bzr0014/git/watson/virt/lib/python2.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
pylab.rcParams['figure.figsize'] = (25, 9)
ax = plt.subplot(1, 1, 1)
legends = []
mit_count = cancer_count = 0
for chosen_cell in mics:
    for cell in mics[chosen_cell]:
        if cell < chosen_cell:
            continue
        y = np.nanmean(mics[chosen_cell][cell][:,indices], axis=0)
        x = np.array(range(len(y)))
        xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
        y_smooth = spline(x, y,xnew)
        if chosen_cell == 'mit' or cell == 'mit':
            color = mit_colors[mit_count]
            mit_count += 1
        else:
            color = cancer_colors[cancer_count]
            cancer_count += 1 
        ax.scatter(x, y, color=color)
        tmp, = ax.plot(xnew, y_smooth, marker=" ", label="%s vs %s"%(chosen_cell.upper(), cell.upper())\
                       , linewidth=4, alpha=.5, color=color)
        #tmp, = ax.plot(x, y, marker=".", label="%s vs %s"%(chosen_cell, cell))
        legends.append(tmp)
        ax.set_xlabel('Orbit', fontsize=25)
        ax.set_ylabel('MIC', fontsize=25)
plt.legend(handles=legends, loc=1, prop={'size':15})
plt.show()
# Out:
# /home/bzr0014/git/watson/virt/lib/python2.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.
#   if sys.path[0] == '':

# %% [markdown]
# ## MIC statsitical analysis

# %% [markdown]
# ### Comparison between contact maps

# %% [markdown]
# ### Comparison between contact maps only considering non-zero orbits

# %% [markdown]
# ### Comparison between orbits

# %% [markdown]
# ### Comparison between orbits only for intra-chromosomal contact maps

# %%
numData = 0
for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue
        datashape = mics[cell1][cell2].shape
        numData += 1
axis = 1
xIndices = range(276)
yIndices = range(73)
yIndices = indices
averages = []
counts = []
data = {}
count = 0
for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue        
        tag = "%s vs %s"%(cell1, cell2)
        tmp = mics[cell1][cell2][xIndices, :][:, yIndices]
        averages.append(np.mean(tmp, axis=1-axis))
        counts.append(tmp.shape[1-axis])           
        if axis == 1:
            data[tag] = tmp
        else:
            data[tag] = tmp.T
        count += 1
averages = np.array(averages)
counts = np.array(counts, dtype='uint32').reshape(-1, 1)
print(averages.shape)
# Out:
# (6, 23)

# %%
print(data.keys())
manova(data, method='wilk')
# Out:
# ['all vs rl', 'call4 vs mit', 'mit vs rl', 'all vs call4', 'all vs mit', 'call4 vs rl']
# Method Used: WILK
# ('n: ', 1656.0)
# ('k: ', 23)
# ('m: ', 6)
# ('a: ', 1640.5)
# ('b_num', 13221.0)
# ('b_denom', 549.0)
# ('b: ', 4.907338098512752)
# ('c: ', 56.5)
# ('gamma: ', 0.5654068065417478)
# ('s', 5)
# ('t', 8.5)
# ('u', 813.0)
# ('df1', 115)
# ('df2', 7993.988150610169)
# ('F', 8.565054626003658)
# ('alpha:', 0.05)
# ('F-crit:', 1.2284905642879855)
# ('p-value:', 1.1711969397971584e-128)

# %%
pylab.rcParams['figure.figsize'] = (25, 9)
chr1 = 14
custIndices = []
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
mit_count = cancer_count = 0
ax = plt.subplot(1, 1, 1)
i = -1
mit_count = cancer_count = 0
for tag in data:
    i += 1
    print(averages.shape)
    means = np.mean(averages, axis=0)
    y = (np.nanmean(data[tag], axis=0) - means)
    x = np.array(range(len(y)))
    xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
    y_smooth = spline(x, y,xnew)
    ax.scatter(x, y)
    if tag.find('mit') >= 0:
        color = mit_colors[mit_count]
        mit_count += 1
    else:
        color = cancer_colors[cancer_count]        
        cancer_count += 1
    ax.plot(xnew, y_smooth, marker=" ", label="%s"%(tag.upper())\
            , linewidth=4,  alpha=.5, color=color)       
    #ax.plot(x, y, marker=".", label="%s vs %s"%(cell1, cell2))
    #ax.set_ylim([-1.5, 1.5])
    ax.set_ylabel('Average loci-loci distance', fontsize=12)
    ax.set_xlabel('Contact maps of chromosome %d'%(chr1), fontsize=12)
    ax.set_ylabel('Corrected Average MIC', fontsize=20)
    ax.set_xlabel('Contact maps of chromosome %d'%(chr1), fontsize=20)
    ax.set_xlabel('Orbits', fontsize=20)    
    #ax.set_xticks(x)
    #ax.set_ylim([-.2, .2])

plt.legend(prop={'size':15})
plt.show()
# Out:
# (6, 23)
# (6, 23)
# (6, 23)
# (6, 23)
# (6, 23)
# (6, 23)
# /home/bzr0014/git/watson/virt/lib/python2.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
newData = {'normal vs cancer':[], 'cancer vs cancer':[]}
for tag in data:
    if tag.find('mit') >= 0:
        newData['normal vs cancer'].append(data[tag])
    else:
        newData['cancer vs cancer'].append(data[tag])
for tag in newData:
    print(tag)
    newData[tag] = np.array(newData[tag])
    newData[tag] = newData[tag].reshape(-1, newData[tag].shape[2])
    print(newData[tag].shape)
# Out:
# normal vs cancer
# (828, 23)
# cancer vs cancer
# (828, 23)

# %%
print(newData.keys())
manova(newData, method='wilk')
# Out:
# ['normal vs cancer', 'cancer vs cancer']
# Method Used: WILK
# ('n: ', 1656.0)
# ('k: ', 23)
# ('m: ', 2)
# ('a: ', 1642.5)
# ('b_num', 525.0)
# ('b_denom', 525.0)
# ('b: ', 1.0)
# ('c: ', 10.5)
# ('gamma: ', 0.8137462912026895)
# ('s', 1)
# ('t', 10.5)
# ('u', 815.0)
# ('df1', 23)
# ('df2', 1632.0)
# ('F', 16.240830195044396)
# ('alpha:', 0.05)
# ('F-crit:', 1.5358774221121692)
# ('p-value:', 7.068138545917349e-58)

# %%
pylab.rcParams['figure.figsize'] = (25, 9)
chr1 = 14
custIndices = []
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
mit_count = cancer_count = 0
ax = plt.subplot(1, 1, 1)
i = -1
mit_count = cancer_count = 0
for tag in newData:
    i += 1
    print(averages.shape)
    means = np.mean(averages, axis=0)
    y = (np.mean(newData[tag], axis=0) - means)
    y_err = np.std(newData[tag], axis=0) * .1
    x = np.array(range(len(y)))
    xnew = np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
    y_smooth = spline(x, y,xnew)
    if tag == 'normal vs cancer':
        color1 = mit_colors[0]
        color2 = mit_colors[1]
    else:
        color1 = cancer_colors[0]
        color2 = cancer_colors[1]
    ax.scatter(x, y)
    ax.plot(xnew, y_smooth, marker=" ", label="%s"%(tag.upper())\
            , linewidth=4,  alpha=.5, color=color1)
    #ax.errorbar(x, y, yerr=y_err, linestyle="dashed", marker="None", color=color2)
    #ax.plot(x, y, marker=".", label="%s vs %s"%(cell1, cell2))
    #ax.set_ylim([-1.5, 1.5])
    ax.set_ylabel('Corrected Average MIC', fontsize=20)
    ax.set_xlabel('Contact maps of chromosome %d'%(chr1), fontsize=20)
    ax.set_xlabel('Contact Maps', fontsize=20)
    #ax.set_xticks(x)
    #ax.set_ylim([-.3, .3])

plt.legend(prop={'size':15})
plt.show()
# Out:
# (6, 23)
# (6, 23)
# /home/bzr0014/git/watson/virt/lib/python2.7/site-packages/ipykernel_launcher.py:21: DeprecationWarning: `spline` is deprecated!
# spline is deprecated in scipy 0.19.0, use Bspline class instead.

# %%
numData = 0
for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue
        datashape = distances[cell1][cell2].shape
        #print(datashape)
        numData += 1
axis = 1
xIndices = range(276)
yIndices = range(1)
yIndices = indices
averages = []
counts = []
data = {}
count = 0
for cell1 in cells:
    for cell2 in cells:
        if cell2 <= cell1:
            continue        
        tag = "%s vs %s"%(cell1, cell2)
        tmp = distances[cell1][cell2][:, 0].reshape(-1, 1)
        averages.append(np.mean(tmp, axis=1-axis))
        counts.append(tmp.shape[1-axis])           
        if axis == 1:
            data[tag] = tmp
        else:
            data[tag] = tmp.T
        count += 1
averages = np.array(averages)
counts = np.array(counts, dtype='uint32').reshape(-1, 1)
#print(averages.shape)
manova(data, method='wilk')
# Out:
# Method Used: WILK
# ('n: ', 1656.0)
# ('k: ', 1)
# ('m: ', 6)
# ('a: ', 1651.5)
# ('b_num', 21.0)
# ('b_denom', 21.0)
# ('b: ', 1.0)
# ('c: ', 1.5)
# ('gamma: ', 0.9111131405886976)
# ('s', 1)
# ('t', 1.5)
# ('u', 824.0)
# ('df1', 5)
# ('df2', 1650.0)
# ('F', 32.19431517229249)
# ('alpha:', 0.05)
# ('F-crit:', 2.219521132720305)
# ('p-value:', 2.1404345664824635e-31)

# %%
pylab.rcParams['figure.figsize'] = (15, 3)
chr1 = 14
custIndices = []
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
mit_count = cancer_count = 0
ax = plt.subplot(1, 1, 1)
i = -1
mit_count = cancer_count = 0
for tag in data:
    i += 1
    print(averages.shape)
    means = np.mean(averages, axis=0)
    x = (np.mean(data[tag], axis=0) - means)
    x_err = np.std(data[tag], axis=0) * .05
    y = np.ones_like(x) * i*.1
    xnew = x#np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
    y_smooth = y#spline(x, y,xnew)
    if tag.find('mit') >= 0:
        color1 = mit_colors[mit_count]
        color2 = mit_colors[mit_count]
        mit_count+=1
    else:
        color1 = cancer_colors[cancer_count]
        color2 = cancer_colors[cancer_count]
        cancer_count += 1
    ax.plot(xnew, y_smooth, marker="o", label="%s"%(tag.upper())\
            , linewidth=5,  alpha=.5, color=color1)
    ax.errorbar(x, y, xerr=x_err, linestyle="dashed", marker="None", color=color1, linewidth=5)
    #ax.plot(x, y, marker=".", label="%s vs %s"%(cell1, cell2))
    #ax.set_ylim([-1.5, 1.5])
    #ax.set_ylabel('Corrected Average MIC', fontsize=20)
ax.set_xlabel('Corrected Average Distance', fontsize=20)
ax.set_yticks(np.arange(len(data))*.1)
ax.set_yticklabels(data.keys())
ax.set_xlim([-.12, .1])

#plt.legend(prop={'size':15})
plt.show()
# Out:
# (6, 1)
# (6, 1)
# (6, 1)
# (6, 1)
# (6, 1)
# (6, 1)

# %%
newData = {'normal vs cancer':[], 'cancer vs cancer':[]}
for tag in data:
    if tag.find('mit') >= 0:
        newData['normal vs cancer'].append(data[tag])
    else:
        newData['cancer vs cancer'].append(data[tag])
for tag in newData:
    #print(tag)
    newData[tag] = np.array(newData[tag])
    newData[tag] = newData[tag].reshape(-1, newData[tag].shape[2])
    #print(newData[tag].shape)

# %%
print(newData.keys())
manova(newData, method='hotelling')
# Out:
# ['normal vs cancer', 'cancer vs cancer']
# Method Used: HOTELLING
# ('n: ', 1656.0)
# ('k: ', 1)
# ('m: ', 2)
# ('s', 1)
# ('t', -0.5)
# ('u', 826.0)
# ('T20: ', 0.012390436681119634)
# ('df1', 1.0)
# ('df2', 1654.0)
# ('F', 20.493782270571874)
# ('alpha:', 0.05)
# ('F-crit:', 3.8470871354481613)
# ('p-value:', 6.409969039925188e-06)

# %%
pylab.rcParams['figure.figsize'] = (15, 3)
chr1 = 14
custIndices = []
for chr2 in range(1, 24):
    if chr1 < chr2:
        custIndices.append(chr2count[(chr1, chr2)])
    else:
        custIndices.append(chr2count[(chr2, chr1)])
mit_count = cancer_count = 0
ax = plt.subplot(1, 1, 1)
i = -1
mit_count = cancer_count = 0
for tag in newData:
    i += 1
    print(averages.shape)
    means = np.mean(averages, axis=0)
    x = (np.mean(newData[tag], axis=0) - means)
    x_err = np.std(newData[tag], axis=0) * .1
    y = np.ones_like(x) * i*.1
    xnew = x#np.linspace(x.min(),x.max(),500) #300 represents number of points to make between T.min and T.max
    y_smooth = y#spline(x, y,xnew)
    if tag == 'normal vs cancer':
        color1 = mit_colors[0]
        color2 = mit_colors[1]
    else:
        color1 = cancer_colors[0]
        color2 = cancer_colors[1]    
    #ax.scatter(x, y)
    ax.plot(xnew, y_smooth, marker="o", label="%s"%(tag.upper())\
            , linewidth=3,  alpha=.5, color=color1)
    ax.errorbar(x, y, xerr=x_err, linestyle="dashed", marker="None", color=color1)
    #ax.plot(x, y, marker=".", label="%s vs %s"%(cell1, cell2))
    #ax.set_ylim([-1.5, 1.5])
    #ax.set_ylabel('Corrected Average MIC', fontsize=20)
    ax.set_xlabel('Corrected Average Distance', fontsize=20)
    ax.set_yticks(np.arange(len(newData))*.1)
    ax.set_yticklabels(newData.keys())
    ax.set_xlim([-.075, .050])

#plt.legend(prop={'size':15})
plt.show()
# Out:
# (6, 1)
# (6, 1)
