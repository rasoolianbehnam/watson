# %% [markdown]
# In this notebook, first I perform the most lates normalization method that I have found to be most useful: a combination of gaussian normalization, SCN and pearson correlation, in the same order mentioned. The normalized results are of type pearson(scn(gaussian

# %%
import numpy as np
import cv2
from utility import *
import matplotlib.pyplot as plt
from iced import normalization
from iced import filter
import os
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %%
def log(image):
    out = image * 1.
    out[np.where(out <= 0)] = 1
    return np.log(out)

def pearsonII(image):
    out = pearson(image)
    out[np.where(out <= 0)] = 0
    return out

def rel_error(m1 ,m2):
    diff = np.abs(m1 - m2)
    return diff / (np.abs(np.minimum(m1+100, m2+100)))

def print_statistics(m1, text = "", print_results=True):
    max = np.max(m1)
    min = np.min(m1)
    mean = m1.mean()
    median = np.percentile(m1, 50)
    std = m1.std()
    if (print_results):
        print("#-----------------------------------------------------------------------#")
        print("Stats for %s: "% text)
        print("max: %f | min: %f | median: %f | mean: %f | std: %f"%(max, min, median, mean, std))
        print("#-----------------------------------------------------------------------#")
    return max, min, mean, std

def t_test(m1, m2=None):
    if m2 == None:
        diff = m1
    else:
        diff = m1 - m2
    n = diff.shape[0] * diff.shape[1]
    std = np.sqrt(np.sum(diff * diff) / (n - 1))
    t0 = diff.mean() * np.sqrt(n) / std
    return t0

def threshold_within_std(m1, k):
    min, max, mean, std = print_statistics(m1, print_results=False)
    return (m1 > mean - k * std) * (m1 < mean + k * std)

# %% [markdown]
# Initiating matrices

# %%
chr1 = 3
chr2 = chr1
print "chromosome 1: %s, chromosome 2: %s"%(chr1, chr2)
#print observed_mit_original.shape

mit = readMat("../data/extracted_all_contact_MIT/chr_%02d_%02d_500kb.mat"%\
              (chr1, chr2), "\t")
call4 = readMat("../data/extracted_all_contact_call4/chr_%02d_%02d_500kb.mat"%\
                (chr1, chr2), "\t")
rl = readMat("../data/extracted_all_contact_RL/chr_%02d_%02d_500kb.mat"%(chr1, chr2), "\t")
# Out:
# chromosome 1: 3, chromosome 2: 3
# file directory: ../data/extracted_all_contact_MIT/chr_03_03_500kb.mat
# file directory: ../data/extracted_all_contact_call4/chr_03_03_500kb.mat
# file directory: ../data/extracted_all_contact_RL/chr_03_03_500kb.mat

# %%
all = readMat("../data/extracted_all_contact_ALL/chr_%02d_%02d_500kb.mat"%(chr1, chr2), "\t")
# Out:
# file directory: ../data/extracted_all_contact_ALL/chr_03_03_500kb.mat

# %%
n0, m0 = np.shape(mit)
n1, m1 = np.shape(call4)
n2, m2 = np.shape(rl)
n3, m3 = np.shape(all)

n = np.min([n0, m0, n1, m1, n2, m2, n3, m3])
mit = mit[:n, :n]
call4 = call4[:n, :n]
rl = rl[:n, :n]
all = all[:n, :n]

# %%
mit = pearson(scn(gaussian_normalize(mit)))
call4 = pearson(scn(gaussian_normalize(call4)))
rl = pearson(scn(gaussian_normalize(rl)))
print call4.shape
# Out:
# (391, 391)

# %%
all = pearson(scn(normalize(rl)))

# %%
min, max, mean_mit, std_mit = print_statistics(mit, "mit")
min, max, mean_rl, std_rl = print_statistics(rl, "rl")
min, max, mean_call4, std_call4 = print_statistics(call4, "call4")
min, max, mean_all, std_all = print_statistics(all, "all")
# Out:
# #-----------------------------------------------------------------------#
# Stats for mit:
# max: 1.000000 | min: -0.057665 | median: -0.007164 | mean: 0.000825 | std: 0.054108
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for rl:
# max: 1.000000 | min: -0.053589 | median: -0.002150 | mean: 0.000433 | std: 0.050681
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for call4:
# max: 1.000000 | min: -0.032048 | median: -0.002314 | mean: 0.000182 | std: 0.050644
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for all:
# max: 1.000000 | min: -0.081476 | median: -0.002772 | mean: 0.000354 | std: 0.050826
# #-----------------------------------------------------------------------#

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
images = [
        (call4) > 0
        , (mit) > 0
        , (rl) > 0
        , (all) > 0
        ]
showImages(images, 1)
# Out:
# Number of columnts: 4

# %%
images = [
        np.log(call4+1)
        , np.log(mit+1)
        , np.log(rl+1)
        , np.log(all+1)
        ]
showImages(images, 1)
# Out:
# Number of columnts: 4

# %%
convertBinaryMatToOrcaReadable(call4 > 0, "data/chr%02d_chr%02d_call4.edges"%(chr1, chr1))
convertBinaryMatToOrcaReadable(mit > 0, "data/chr%02d_chr%02d_mit.edges"%(chr1, chr1))
convertBinaryMatToOrcaReadable(rl > 0, "data/chr%02d_chr%02d_rl.edges"%(chr1, chr1))
convertBinaryMatToOrcaReadable(all > 0, "data/chr%02d_chr%02d_all.edges"%(chr1, chr1))

# %%
os.system('Rscript rscript.r %s'%chr1)
# Out:
# 0

# %%
graphlets_mit = readMat("data/chr%02d_chr%02d_mit.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
graphlets_all = readMat("data/chr%02d_chr%02d_all.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
graphlets_rl = readMat("data/chr%02d_chr%02d_rl.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
graphlets_call4 = readMat("data/chr%02d_chr%02d_call4.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
print(graphlets_mit.shape)
print(graphlets_all.shape)
print(graphlets_rl.shape)
print(graphlets_call4.shape)
# Out:
# file directory: data/chr03_chr03_mit.graphlets
# file directory: data/chr03_chr03_all.graphlets
# file directory: data/chr03_chr03_rl.graphlets
# file directory: data/chr03_chr03_call4.graphlets
# (391, 73)
# (391, 73)
# (391, 73)
# (391, 73)

# %%
mit_all_corr = \
    graphlet_correlational_distance(graphlets_mit, graphlets_all)

# %%
mit_mit_corr = \
    graphlet_correlational_distance(graphlets_mit, graphlets_mit)

# %%
mit_call4_corr = \
    graphlet_correlational_distance(graphlets_mit, graphlets_call4)

# %%
mit_rl_corr = \
    graphlet_correlational_distance(graphlets_mit, graphlets_rl)

# %%
images = [ mit_mit_corr
          , mit_all_corr
         , mit_rl_corr
         , mit_call4_corr]
showImages(images, 2)
# Out:
# Number of columnts: 2

# %%
print_statistics(mit_mit_corr)
print_statistics(mit_all_corr)
print_statistics(mit_rl_corr)
print_statistics(mit_call4_corr)
# Out:
# #-----------------------------------------------------------------------#
# Stats for :
# max: 1.464597 | min: 0.000000 | median: 0.141609 | mean: 0.183276 | std: 0.153546
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for :
# max: 2.207065 | min: 0.658505 | median: 1.365477 | mean: 1.373682 | std: 0.179704
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for :
# max: 4.118116 | min: 1.068633 | median: 2.239338 | mean: 2.288463 | std: 0.298913
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for :
# max: 4.469617 | min: 3.400858 | median: 4.081259 | mean: 4.075095 | std: 0.148007
# #-----------------------------------------------------------------------#
# (4.469616723064088, 3.4008584941455666, 4.07509450538009, 0.14800683174023457)

# %%
print_statistics(np.diagonal(mit_mit_corr))
print_statistics(np.diagonal(mit_all_corr))
print_statistics(np.diagonal(mit_rl_corr))
print_statistics(np.diagonal(mit_call4_corr))
# Out:
# #-----------------------------------------------------------------------#
# Stats for :
# max: 0.000000 | min: 0.000000 | median: 0.000000 | mean: 0.000000 | std: 0.000000
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for :
# max: 2.161133 | min: 0.719218 | median: 1.363225 | mean: 1.374714 | std: 0.174143
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for :
# max: 4.117633 | min: 1.410812 | median: 2.243016 | mean: 2.286506 | std: 0.312053
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for :
# max: 4.469550 | min: 3.662796 | median: 4.077379 | mean: 4.075067 | std: 0.147716
# #-----------------------------------------------------------------------#
# (4.469550226150505, 3.6627957656735335, 4.075067173766815, 0.14771571662588764)

# %%
graphlets = {'mit' : graphlets_mit
            , 'all' : graphlets_all
            , 'rl' : graphlets_rl
            , 'call4' : graphlets_call4}
pair_orbits(graphlets, chr1)
# Out:
# shape of graphlet for chromosome 3 of cell rl:                 391 by 73
# shape of graphlet for chromosome 3 of cell call4:                 391 by 73
# shape of graphlet for chromosome 3 of cell all:                 391 by 73
# shape of graphlet for chromosome 3 of cell mit:                 391 by 73
# ('number of matrices:', 4)
# data/chr03_orbit00.paired.csv
# data/chr03_orbit01.paired.csv
# data/chr03_orbit02.paired.csv
# data/chr03_orbit03.paired.csv
# data/chr03_orbit04.paired.csv
# data/chr03_orbit05.paired.csv
# data/chr03_orbit06.paired.csv
# data/chr03_orbit07.paired.csv
# data/chr03_orbit08.paired.csv
# data/chr03_orbit09.paired.csv
# data/chr03_orbit10.paired.csv
# data/chr03_orbit11.paired.csv
# data/chr03_orbit12.paired.csv
# data/chr03_orbit13.paired.csv
# data/chr03_orbit14.paired.csv
# data/chr03_orbit15.paired.csv
# data/chr03_orbit16.paired.csv
# data/chr03_orbit17.paired.csv
# data/chr03_orbit18.paired.csv
# data/chr03_orbit19.paired.csv
# data/chr03_orbit20.paired.csv
# data/chr03_orbit21.paired.csv
# data/chr03_orbit22.paired.csv
# data/chr03_orbit23.paired.csv
# data/chr03_orbit24.paired.csv
# data/chr03_orbit25.paired.csv
# data/chr03_orbit26.paired.csv
# data/chr03_orbit27.paired.csv
# data/chr03_orbit28.paired.csv
# data/chr03_orbit29.paired.csv
# data/chr03_orbit30.paired.csv
# data/chr03_orbit31.paired.csv
# data/chr03_orbit32.paired.csv
# data/chr03_orbit33.paired.csv
# data/chr03_orbit34.paired.csv
# data/chr03_orbit35.paired.csv
# data/chr03_orbit36.paired.csv
# data/chr03_orbit37.paired.csv
# data/chr03_orbit38.paired.csv
# data/chr03_orbit39.paired.csv
# data/chr03_orbit40.paired.csv
# data/chr03_orbit41.paired.csv
# data/chr03_orbit42.paired.csv
# data/chr03_orbit43.paired.csv
# data/chr03_orbit44.paired.csv
# data/chr03_orbit45.paired.csv
# data/chr03_orbit46.paired.csv
# data/chr03_orbit47.paired.csv
# data/chr03_orbit48.paired.csv
# data/chr03_orbit49.paired.csv
# data/chr03_orbit50.paired.csv
# data/chr03_orbit51.paired.csv
# data/chr03_orbit52.paired.csv
# data/chr03_orbit53.paired.csv
# data/chr03_orbit54.paired.csv
# data/chr03_orbit55.paired.csv
# data/chr03_orbit56.paired.csv
# data/chr03_orbit57.paired.csv
# data/chr03_orbit58.paired.csv
# data/chr03_orbit59.paired.csv
# data/chr03_orbit60.paired.csv
# data/chr03_orbit61.paired.csv
# data/chr03_orbit62.paired.csv
# data/chr03_orbit63.paired.csv
# data/chr03_orbit64.paired.csv
# data/chr03_orbit65.paired.csv
# data/chr03_orbit66.paired.csv
# data/chr03_orbit67.paired.csv
# data/chr03_orbit68.paired.csv
# data/chr03_orbit69.paired.csv
# data/chr03_orbit70.paired.csv
# data/chr03_orbit71.paired.csv
# data/chr03_orbit72.paired.csv

# %%
for orbit in range(73):
    file_name = "data/chr%02d_orbit%02d.paired.csv"%(chr1, orbit)
    command = "java -jar mine.jar %s -allPairs"%file_name
    os.system(command)

# %%
pairwise_hic = {}
for key in graphlets:
    pairwise_hic = {}
    for key in graphlets:
        pairwise_hic[key] = {}
for orbit in range(73):
    var1, var2, mic = get_mic_from_file\
        ("data/chr%02d_orbit%02d.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"\
         %(chr1, orbit))
    n = len(var1)
    for i in range(n):
        pairwise_hic[var1[i]][var2[i]] = mic[i]
        pairwise_hic[var2[i]][var1[i]] = mic[i]
# Out:
# data/chr03_orbit00.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit01.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit02.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit03.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit04.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit05.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit06.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit07.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit08.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit09.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit10.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit11.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit12.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit13.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit14.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit15.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit16.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit17.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit18.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit19.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit20.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit21.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit22.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit23.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit24.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit25.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit26.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit27.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit28.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit29.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit30.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit31.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit32.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit33.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit34.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit35.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit36.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit37.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit38.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit39.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit40.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit41.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit42.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit43.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit44.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit45.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit46.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit47.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit48.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit49.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit50.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit51.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit52.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit53.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit54.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit55.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit56.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit57.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit58.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit59.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit60.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit61.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit62.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit63.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit64.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit65.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit66.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit67.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit68.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit69.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit70.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit71.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv
# data/chr03_orbit72.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv

# %%
pairwise_hic
# Out:
# {'all': {'call4': '0.13535', 'mit': '0.25577', 'rl': '0.48355'},
#  'call4': {'all': '0.13535', 'mit': '0.15115', 'rl': '0.12401'},
#  'mit': {'all': '0.25577', 'call4': '0.15115', 'rl': '0.31738'},
#  'rl': {'all': '0.48355', 'call4': '0.12401', 'mit': '0.31738'}}

# %%
pairwise_hic_chr = [[], [], []]
for chr1 in range(1, 23):
    if chr1 == 19 or chr1 == 22:
        continue
    pairwise_hic = {}
    for key in graphlets:
        pairwise_hic = {}
        for key in graphlets:
            pairwise_hic[key] = {}
    for orbit in range(73):
        var1, var2, mic = get_mic_from_file\
            ("data/chr%02d_orbit%02d.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"\
             %(chr1, orbit))
        n = len(var1)
        for i in range(n):
            pairwise_hic[var1[i]][var2[i]] = mic[i]
            pairwise_hic[var2[i]][var1[i]] = mic[i]
        pairwise_hic_chr[0].append(pairwise_hic['mit']['all'])
        pairwise_hic_chr[1].append(pairwise_hic['mit']['rl'])
        pairwise_hic_chr[2].append(pairwise_hic['mit']['call4'])
print("************************************************")
for i in pairwise_hic_chr:
    print i
# Out:
# ************************************************
# [0.11822, 0.15751, 0.17345, 0.2747, 0.18143, 0.16579, 0.23255, 0.17682, 0.22151, 0.18092, 0.25482, 0.19538, 0.42325, 0.24972, 0.36349, 0.19875, 0.16466, 0.20431, 0.17964, 0.16785, 0.20876, 0.18856, 0.21443, 0.18495, 0.17491, 0.19451, 0.16556, 0.16192, 0.15105, 0.23283, 0.17533, 0.18955, 0.18654, 0.16645, 0.18049, 0.17274, 0.16298, 0.1627, 0.16978, 0.17214, 0.34092, 0.22733, 0.20927, 0.35678, 0.2022, 0.20116, 0.43068, 0.23112, 0.2236, 0.20068, 0.17229, 0.20738, 0.34572, 0.21933, 0.411, 0.19648, 0.20955, 0.32864, 0.26098, 0.51546, 0.28061, 0.2005, 0.3051, 0.27216, 0.29159, 0.46958, 0.40653, 0.25953, 0.3683, 0.25674, 0.44706, 0.32614, 0.42241, 0.09369, 0.18319, 0.16629, 0.2529, 0.16218, 0.17649, 0.1585, 0.16997, 0.18323, 0.19131, 0.31373, 0.16977, 0.40909, 0.24781, 0.31542, 0.19065, 0.17718, 0.17923, 0.18169, 0.19382, 0.18628, 0.18256, 0.17196, 0.19906, 0.17841, 0.28043, 0.17551, 0.2221, 0.16418, 0.19344, 0.17402, 0.1951, 0.32261, 0.18888, 0.1637, 0.17116, 0.18111, 0.17823, 0.16902, 0.19126, 0.40427, 0.28376, 0.19379, 0.25219, 0.15356, 0.16635, 0.42085, 0.20276, 0.23097, 0.17926, 0.19471, 0.18799, 0.31516, 0.2165, 0.38418, 0.23392, 0.21667, 0.41604, 0.2385, 0.43826, 0.34761, 0.18168, 0.26284, 0.29621, 0.29773, 0.40422, 0.48771, 0.29993, 0.41182, 0.24684, 0.52044, 0.31634, 0.36257, 0.11237, 0.1912, 0.1903, 0.17726, 0.19234, 0.17097, 0.16298, 0.17334, 0.1957, 0.17814, 0.17348, 0.19147, 0.21264, 0.17018, 0.20953, 0.17693, 0.18254, 0.18729, 0.1696, 0.17566, 0.16271, 0.16324, 0.17169, 0.19235, 0.17877, 0.2008, 0.1776, 0.17373, 0.19305, 0.173, 0.18796, 0.19182, 0.19878, 0.20595, 0.16047, 0.20667, 0.18757, 0.19367, 0.18855, 0.18328, 0.18506, 0.20544, 0.18214, 0.22963, 0.18619, 0.19208, 0.3396, 0.17617, 0.16905, 0.18742, 0.18256, 0.18251, 0.23726, 0.17612, 0.25771, 0.21254, 0.19338, 0.17087, 0.16817, 0.33621, 0.18896, 0.15217, 0.22635, 0.16518, 0.18597, 0.29088, 0.20439, 0.18327, 0.18804, 0.17048, 0.28237, 0.16863, 0.25577, 0.09457, 0.17495, 0.15515, 0.18184, 0.24537, 0.18749, 0.23735, 0.21674, 0.19865, 0.20282, 0.19955, 0.16538, 0.30968, 0.22321, 0.20892, 0.2016, 0.22011, 0.2087, 0.20325, 0.29947, 0.21867, 0.20011, 0.2533, 0.18858, 0.18067, 0.16745, 0.17611, 0.20339, 0.18659, 0.17189, 0.17129, 0.18065, 0.21732, 0.19454, 0.18668, 0.2152, 0.17371, 0.17171, 0.19027, 0.16378, 0.25967, 0.18505, 0.19622, 0.26436, 0.16325, 0.1901, 0.31985, 0.20597, 0.19525, 0.24116, 0.19686, 0.27172, 0.30659, 0.22037, 0.33487, 0.22109, 0.19518, 0.2329, 0.18933, 0.4405, 0.25364, 0.21165, 0.33007, 0.23992, 0.23311, 0.4925, 0.3375, 0.23039, 0.27897, 0.20754, 0.35463, 0.26094, 0.24576, 0.10766, 0.19151, 0.19865, 0.16697, 0.22451, 0.24018, 0.20106, 0.20801, 0.2532, 0.24756, 0.29862, 0.19736, 0.28599, 0.2029, 0.16148, 0.26401, 0.26589, 0.22318, 0.23926, 0.19046, 0.22377, 0.23959, 0.19898, 0.20956, 0.18774, 0.31178, 0.1892, 0.22925, 0.20713, 0.22676, 0.19262, 0.21399, 0.36746, 0.21576, 0.23147, 0.17843, 0.19459, 0.27775, 0.19641, 0.23531, 0.39973, 0.26254, 0.17591, 0.50388, 0.24063, 0.21627, 0.43168, 0.22041, 0.24151, 0.354, 0.22001, 0.42495, 0.50053, 0.22835, 0.38753, 0.21701, 0.17729, 0.21364, 0.19527, 0.43536, 0.325, 0.19351, 0.36928, 0.26639, 0.34569, 0.32017, 0.25784, 0.18856, 0.23286, 0.2054, 0.24399, 0.1738, 0.193, 0.11564, 0.20382, 0.19527, 0.21867, 0.23714, 0.19326, 0.18763, 0.20004, 0.23059, 0.22195, 0.31722, 0.20535, 0.38407, 0.2288, 0.29804, 0.32394, 0.19444, 0.18946, 0.33605, 0.22605, 0.19663, 0.21085, 0.18882, 0.19804, 0.21284, 0.31188, 0.20712, 0.26974, 0.19164, 0.26333, 0.2173, 0.17885, 0.30143, 0.16379, 0.17871, 0.22173, 0.21091, 0.20496, 0.22512, 0.20836, 0.37827, 0.20776, 0.20235, 0.39441, 0.20525, 0.24195, 0.39932, 0.23618, 0.23497, 0.27743, 0.18212, 0.27873, 0.367, 0.23596, 0.3098, 0.18895, 0.21594, 0.33602, 0.24831, 0.36339, 0.32955, 0.20136, 0.25703, 0.26578, 0.31767, 0.32349, 0.3665, 0.25042, 0.26642, 0.18124, 0.36968, 0.20694, 0.26431, 0.15394, 0.221, 0.22552, 0.19066, 0.22877, 0.20635, 0.22105, 0.20701, 0.23955, 0.1988, 0.28217, 0.2185, 0.35 ...
# [0.23681, 0.36773, 0.21747, 0.39135, 0.40077, 0.24847, 0.24259, 0.19899, 0.34694, 0.25387, 0.41012, 0.27196, 0.48312, 0.35468, 0.45691, 0.31013, 0.22686, 0.22574, 0.24895, 0.22549, 0.24974, 0.20949, 0.1639, 0.19284, 0.20468, 0.39455, 0.27466, 0.36029, 0.24972, 0.44372, 0.29798, 0.17112, 0.38881, 0.21582, 0.34578, 0.25101, 0.37747, 0.34644, 0.24355, 0.22327, 0.43178, 0.34594, 0.27701, 0.46633, 0.23089, 0.28732, 0.49819, 0.28718, 0.3792, 0.38012, 0.30978, 0.38087, 0.48502, 0.33643, 0.44975, 0.30903, 0.30107, 0.45735, 0.35555, 0.5002, 0.41044, 0.31783, 0.4109, 0.38064, 0.40193, 0.44864, 0.47611, 0.38549, 0.44472, 0.33429, 0.53081, 0.41218, 0.48445, 0.20385, 0.22906, 0.20421, 0.39825, 0.23272, 0.16149, 0.18214, 0.19027, 0.22282, 0.15939, 0.4021, 0.23305, 0.54721, 0.37613, 0.48971, 0.24204, 0.20659, 0.17821, 0.26848, 0.19093, 0.21066, 0.16488, 0.17399, 0.19696, 0.17478, 0.36671, 0.2121, 0.22281, 0.16772, 0.3362, 0.21877, 0.23022, 0.42161, 0.17742, 0.19428, 0.28722, 0.17754, 0.20336, 0.18398, 0.23254, 0.48934, 0.34549, 0.24918, 0.31522, 0.20407, 0.32278, 0.47674, 0.23126, 0.37448, 0.22367, 0.20116, 0.1774, 0.47175, 0.24818, 0.41823, 0.30284, 0.24972, 0.51305, 0.31292, 0.49148, 0.42127, 0.29185, 0.24974, 0.30908, 0.41262, 0.4107, 0.64034, 0.3904, 0.5411, 0.32703, 0.65584, 0.50993, 0.48312, 0.11195, 0.18055, 0.18316, 0.21062, 0.21264, 0.22343, 0.17557, 0.17192, 0.20174, 0.19582, 0.26388, 0.19789, 0.26693, 0.21587, 0.31944, 0.18911, 0.18197, 0.16318, 0.17876, 0.16543, 0.18297, 0.16928, 0.17502, 0.15624, 0.18886, 0.25056, 0.17293, 0.19443, 0.17573, 0.30167, 0.1906, 0.19816, 0.24004, 0.18906, 0.20296, 0.25885, 0.2307, 0.21536, 0.17274, 0.17961, 0.2738, 0.18692, 0.18042, 0.30639, 0.20084, 0.23071, 0.4404, 0.19227, 0.22301, 0.17899, 0.16826, 0.21944, 0.38434, 0.19336, 0.30722, 0.1497, 0.18257, 0.30353, 0.21059, 0.39158, 0.20357, 0.17783, 0.20678, 0.19083, 0.21051, 0.23244, 0.32254, 0.23194, 0.21543, 0.16714, 0.30497, 0.27498, 0.31738, 0.1043, 0.21575, 0.13267, 0.20262, 0.29821, 0.19807, 0.1878, 0.19688, 0.22467, 0.31002, 0.2719, 0.19099, 0.34295, 0.22085, 0.22721, 0.18789, 0.1858, 0.17117, 0.20561, 0.21826, 0.17125, 0.20969, 0.31437, 0.2148, 0.26237, 0.25414, 0.22343, 0.1861, 0.21311, 0.25644, 0.19695, 0.20507, 0.23586, 0.18605, 0.23983, 0.28041, 0.23516, 0.22421, 0.19707, 0.28537, 0.34202, 0.22591, 0.20002, 0.43201, 0.19545, 0.29467, 0.40288, 0.19959, 0.2453, 0.27596, 0.2303, 0.31394, 0.40053, 0.24725, 0.36398, 0.19473, 0.25334, 0.25316, 0.20181, 0.41084, 0.2778, 0.21439, 0.3228, 0.26237, 0.31366, 0.36924, 0.40004, 0.22142, 0.31117, 0.18674, 0.31833, 0.20605, 0.23204, 0.17176, 0.38388, 0.16725, 0.17457, 0.44682, 0.26, 0.39651, 0.17956, 0.28335, 0.40091, 0.42501, 0.22626, 0.25451, 0.17927, 0.19781, 0.26726, 0.18676, 0.25006, 0.26216, 0.39726, 0.31603, 0.21257, 0.34879, 0.20095, 0.35009, 0.51387, 0.27545, 0.34644, 0.28503, 0.32472, 0.2104, 0.35854, 0.5453, 0.17102, 0.34774, 0.38469, 0.32006, 0.40974, 0.23417, 0.32356, 0.50245, 0.31236, 0.20842, 0.56541, 0.21742, 0.40079, 0.45694, 0.24724, 0.28191, 0.39091, 0.24206, 0.36875, 0.60847, 0.26609, 0.34354, 0.18108, 0.30106, 0.23207, 0.20916, 0.41279, 0.2803, 0.25241, 0.32684, 0.24473, 0.28893, 0.28038, 0.30029, 0.20726, 0.26124, 0.19655, 0.20998, 0.17659, 0.22802, 0.20181, 0.36647, 0.20063, 0.33015, 0.52737, 0.24292, 0.34379, 0.2026, 0.27674, 0.38061, 0.46881, 0.25366, 0.49664, 0.2856, 0.39207, 0.47506, 0.23704, 0.2668, 0.53095, 0.47189, 0.21738, 0.19479, 0.29824, 0.17627, 0.41911, 0.52766, 0.32758, 0.51489, 0.24182, 0.44604, 0.24583, 0.29505, 0.50734, 0.20635, 0.34685, 0.41133, 0.33144, 0.35778, 0.25055, 0.31961, 0.52639, 0.35013, 0.23053, 0.56784, 0.1928, 0.50591, 0.54562, 0.36115, 0.38091, 0.23944, 0.21624, 0.34483, 0.52046, 0.31943, 0.40464, 0.25559, 0.32329, 0.46783, 0.28534, 0.51606, 0.40037, 0.27638, 0.26996, 0.31318, 0.32491, 0.46539, 0.50919, 0.30922, 0.31181, 0.19595, 0.44784, 0.31386, 0.35992, 0.19117, 0.29694, 0.17546, 0.3302, 0.31478, 0.2338, 0.20199, 0.15713, 0.23859, 0.18517, 0.415 ...
# [0.13506, 0.19966, 0.16044, 0.17846, 0.23045, 0.155, 0.20893, 0.16879, 0.17342, 0.18517, 0.1939, 0.16466, 0.16255, 0.18171, 0.18674, 0.16867, 0.15016, 0.14624, 0.1583, 0.17746, 0.16695, 0.14234, 0.16871, 0.14461, 0.19942, 0.14832, 0.14632, 0.19209, 0.16681, 0.21971, 0.16393, 0.18073, 0.20213, 0.15771, 0.15956, 0.16503, 0.18266, 0.20077, 0.15724, 0.16816, 0.20026, 0.15199, 0.17395, 0.15949, 0.15625, 0.19206, 0.21267, 0.1387, 0.18153, 0.15993, 0.12738, 0.16315, 0.1544, 0.15608, 0.17917, 0.18519, 0.15421, 0.18277, 0.16479, 0.20283, 0.13042, 0.17756, 0.1524, 0.16647, 0.1443, 0.20229, 0.16619, 0.16579, 0.18168, 0.1571, 0.22931, 0.18697, 0.17595, 0.09577, 0.22836, 0.15773, 0.18165, 0.16879, 0.19953, 0.1812, 0.14751, 0.17273, 0.15683, 0.27402, 0.13326, 0.3261, 0.18926, 0.21284, 0.28187, 0.16312, 0.17527, 0.36022, 0.19373, 0.16632, 0.16563, 0.19228, 0.17364, 0.17851, 0.18711, 0.16998, 0.35177, 0.18799, 0.20635, 0.18166, 0.1858, 0.31075, 0.14917, 0.13512, 0.19657, 0.17933, 0.15073, 0.15516, 0.15771, 0.37304, 0.22491, 0.15506, 0.27717, 0.17109, 0.24288, 0.20886, 0.17919, 0.16931, 0.1458, 0.16911, 0.15922, 0.22539, 0.19509, 0.35961, 0.18104, 0.18661, 0.27809, 0.18687, 0.41248, 0.25407, 0.1797, 0.1419, 0.17823, 0.18764, 0.29515, 0.31527, 0.2026, 0.23205, 0.16418, 0.26442, 0.24216, 0.21081, 0.09556, 0.21617, 0.16497, 0.13718, 0.21533, 0.17737, 0.19925, 0.14512, 0.176, 0.18843, 0.19301, 0.16044, 0.22751, 0.13143, 0.15866, 0.18754, 0.15693, 0.14416, 0.17157, 0.17597, 0.1983, 0.1577, 0.14537, 0.18459, 0.1863, 0.15564, 0.17857, 0.16482, 0.21214, 0.16412, 0.15623, 0.21115, 0.20968, 0.16276, 0.14802, 0.16248, 0.18654, 0.19271, 0.16009, 0.18191, 0.2026, 0.18455, 0.15541, 0.18527, 0.16184, 0.14378, 0.24013, 0.19531, 0.16051, 0.15101, 0.11443, 0.13158, 0.1571, 0.14369, 0.19081, 0.16567, 0.14347, 0.15425, 0.16515, 0.21967, 0.19454, 0.17493, 0.15208, 0.16978, 0.1587, 0.17332, 0.19224, 0.15153, 0.22241, 0.15534, 0.15019, 0.13375, 0.15115, 0.11948, 0.21867, 0.14955, 0.19627, 0.25012, 0.16728, 0.17772, 0.16663, 0.19917, 0.21406, 0.19633, 0.17562, 0.24202, 0.22604, 0.19426, 0.23822, 0.15044, 0.18352, 0.19612, 0.2305, 0.14652, 0.15723, 0.14227, 0.13829, 0.18276, 0.18253, 0.14675, 0.20631, 0.16401, 0.20222, 0.16849, 0.15066, 0.21291, 0.15852, 0.18014, 0.17032, 0.18843, 0.17352, 0.1589, 0.20404, 0.23802, 0.20845, 0.14992, 0.25161, 0.15147, 0.19062, 0.2319, 0.2054, 0.20926, 0.14793, 0.15397, 0.17093, 0.1977, 0.17315, 0.18448, 0.18247, 0.17284, 0.21082, 0.15617, 0.31604, 0.2453, 0.18819, 0.15607, 0.18048, 0.20744, 0.21124, 0.2358, 0.19991, 0.20608, 0.15953, 0.23126, 0.21225, 0.23185, 0.09083, 0.41536, 0.16807, 0.16242, 0.45586, 0.16192, 0.44627, 0.18963, 0.15838, 0.49495, 0.50746, 0.18626, 0.33061, 0.20433, 0.19492, 0.24577, 0.15491, 0.17813, 0.1589, 0.43111, 0.15299, 0.16638, 0.4173, 0.14743, 0.41896, 0.18924, 0.16514, 0.27079, 0.20411, 0.30784, 0.15509, 0.44097, 0.58077, 0.18342, 0.17161, 0.43027, 0.16814, 0.20676, 0.17649, 0.44988, 0.49434, 0.32942, 0.14861, 0.63966, 0.16985, 0.50081, 0.17062, 0.18246, 0.19493, 0.07001, 0.04996, 0.16799, 0.21467, 0.18508, 0.42783, 0.16468, 0.4643, 0.20267, 0.18552, 0.4997, 0.27159, 0.16836, 0.15294, 0.16252, 0.20483, 0.27282, 0.25805, 0.2055, 0.23955, 0.16442, 0.21725, 0.14768, 0.19811, 0.11408, 0.23323, 0.14254, 0.18985, 0.26615, 0.20157, 0.22892, 0.16902, 0.16309, 0.18586, 0.2433, 0.19363, 0.20763, 0.19165, 0.18891, 0.21044, 0.20885, 0.15722, 0.27265, 0.26753, 0.20423, 0.20949, 0.17308, 0.18295, 0.21815, 0.18202, 0.19746, 0.15769, 0.19384, 0.20079, 0.17101, 0.17639, 0.17917, 0.16937, 0.17448, 0.19233, 0.19089, 0.17989, 0.15097, 0.18322, 0.18415, 0.14837, 0.14416, 0.22372, 0.16346, 0.21611, 0.18761, 0.20203, 0.20092, 0.16891, 0.15478, 0.17345, 0.1973, 0.1727, 0.17652, 0.14886, 0.18427, 0.20825, 0.21264, 0.20225, 0.17476, 0.15836, 0.16406, 0.158, 0.14104, 0.18004, 0.19743, 0.18399, 0.14052, 0.09294, 0.17471, 0.15568, 0.16295, 0.16547, 0.32508, 0.19174, 0.19204, 0.30375, 0.18686, 0.1908, 0.19723, 0.25129, 0.19183, 0.37334,  ...

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
mat_all = np.array(pairwise_hic_chr[0]).reshape(-1, 73)
mat_rl = np.array(pairwise_hic_chr[1]).reshape(-1, 73)
mat_call4 = np.array(pairwise_hic_chr[2]).reshape(-1, 73)

x = range(mat_all.shape[0])
ax = plt.subplot(1, 1, 1)
vsAll, = ax.plot(range(20), np.mean(mat_all, axis=1), marker="o")
vsRl, = ax.plot(range(20), np.mean(mat_rl, axis=1), marker="o")
vsCall4, = ax.plot(range(20), np.mean(mat_call4, axis=1), marker="o")
plt.show()
(mat_all.shape)
# Out:
# (20, 73)

# %%
pylab.rcParams['figure.figsize'] = (15, 5)
mat_all = np.array(pairwise_hic_chr[0]).reshape(-1, 73)
mat_rl = np.array(pairwise_hic_chr[1]).reshape(-1, 73)
mat_call4 = np.array(pairwise_hic_chr[2]).reshape(-1, 73)
x = range(mat_all.shape[0])

ax = plt.subplot(1, 1, 1)
vsAll, = ax.plot(range(73), np.mean(mat_all, axis=0), marker="o")
vsRl, = ax.plot(range(73), np.mean(mat_rl, axis=0), marker="o")
vsCall4, = ax.plot(range(73), np.mean(mat_call4, axis=0), marker="o")
plt.show()
(mat_all.shape)
# Out:
# (20, 73)

# %%
pylab.rcParams['figure.figsize'] = (15, 12)
mat_all = np.array(pairwise_hic_chr[0]).reshape(20, 73)
mat_rl = np.array(pairwise_hic_chr[1]).reshape(20, 73)
mat_call4 = np.array(pairwise_hic_chr[2]).reshape(20, 73)
x = range(mat_all.shape[1])

y = np.mean(mat_all, axis=0)
y_error = np.std(mat_all, axis=0)
ax = plt.subplot(3, 1, 1)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")


y = np.mean(mat_rl, axis=0)
y_error = np.std(mat_rl, axis=0)
ax = plt.subplot(3, 1, 2)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")
#vsCall4, = ax.plot(range(73), np.mean(mat_call4, axis=0))

y = np.mean(mat_call4, axis=0)
y_error = np.std(mat_call4, axis=0)
ax = plt.subplot(3, 1, 3)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")
plt.show()
(mat_all.shape)
# Out:
# (20, 73)
