# %% [markdown]
# # Thresholding
# In this notebook, first I perform the most lates normalization method that I have found to be most useful: a combination of gaussian normalization, SCN and pearson correlation, in the same order mentioned. The normalized results are of type pearson(scn(gaussian(graph))).
#
# Then I threshold the results by setting pearson values above 0 to 1 and the rest to 0. I then save the threholded matrix so that orca in R can read it and extract orbits.
#
# I then separate orbits from cell lines and put them together, so orbit 0 of the cells will be in a file, orbits 1 will be in a separate file and so forth until the 72nd orbit.
# I then run mine.jar on the files to extract the pairwise MIC values.

# %%
import numpy as np
import cv2
from utility import *
import matplotlib.pyplot as plt
from iced import normalization
from iced import filter
import os
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/bzr0014/watson/scripts/virt/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# Initiating matrices

# %%
chr1 = 22
chr2 = chr1
print "chromosome 1: %s, chromosome 2: %s"%(chr1, chr2)
#print observed_mit_original.shape

mit = readMat("../data/extracted_all_contact_MIT/chr_%02d_%02d_500kb.mat"%\
              (chr1, chr2), "\t")
call4 = readMat("../data/extracted_all_contact_call4/chr_%02d_%02d_500kb.mat"%\
                (chr1, chr2), "\t")
rl = readMat("../data/extracted_all_contact_RL/chr_%02d_%02d_500kb.mat"%(chr1, chr2), "\t")
# Out:
# chromosome 1: 22, chromosome 2: 22

# %%
all = readMat("../data/extracted_all_contact_ALL/chr_%02d_%02d_500kb.mat"%(chr1, chr2), "\t")

# %%
n0, m0 = np.shape(mit)
n1, m1 = np.shape(call4)
n2, m2 = np.shape(rl)
n3, m3 = np.shape(all)

n = np.min([n0, m0, n1, m1, n2, m2, n3, m3])
mit = mit[:n, :n]
call4 = call4[:n, :n]
rl = rl[:n, :n]
all = all[:n, :n]

# %%
mit = pearson(scn(gaussian_normalize(mit)))
call4 = pearson(scn(gaussian_normalize(call4)))
rl = pearson(scn(gaussian_normalize(rl)))
print call4.shape
# Out:
# (68, 68)

# %%
all = pearson(scn(gaussian_normalize(rl)))

# %%
min, max, mean_mit, std_mit = print_statistics(mit, "mit")
min, max, mean_rl, std_rl = print_statistics(rl, "rl")
min, max, mean_call4, std_call4 = print_statistics(call4, "call4")
min, max, mean_all, std_all = print_statistics(all, "all")
# Out:
# #-----------------------------------------------------------------------#
# Stats for mit:
# max: 1.000000 | min: -0.169688 | median: -0.019126 | mean: 0.004670 | std: 0.132816
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for rl:
# max: 1.000000 | min: -0.733132 | median: 0.002335 | mean: 0.019885 | std: 0.121731
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for call4:
# max: 1.000000 | min: -0.038987 | median: -0.013811 | mean: 0.000796 | std: 0.122390
# #-----------------------------------------------------------------------#
# #-----------------------------------------------------------------------#
# Stats for all:
# max: 1.000000 | min: -0.865232 | median: -0.016949 | mean: 0.001314 | std: 0.125641
# #-----------------------------------------------------------------------#

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
images = [
        (call4) > 0
        , (mit) > 0
        , (rl) > 0
        , (all) > 0
        ]
showImages(images, 1)
# Out:
# Number of columnts: 4

# %%
images = [
        np.log(call4+1)
        , np.log(mit+1)
        , np.log(rl+1)
        , np.log(all+1)
        ]
showImages(images, 1)
# Out:
# Number of columnts: 4

# %%
convertBinaryMatToOrcaReadable(call4 > 0, "data/chr%02d_chr%02d_call4.edges"%(chr1, chr1))
convertBinaryMatToOrcaReadable(mit > 0, "data/chr%02d_chr%02d_mit.edges"%(chr1, chr1))
convertBinaryMatToOrcaReadable(rl > 0, "data/chr%02d_chr%02d_rl.edges"%(chr1, chr1))
convertBinaryMatToOrcaReadable(all > 0, "data/chr%02d_chr%02d_all.edges"%(chr1, chr1))
