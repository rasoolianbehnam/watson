# %% [markdown]
# # Graphlet Analysis
#
# Remember, in notebook *Thresholding*, I thresholded contact maps and save them
# in a way that orca can read them.
#
# In this notebook, I perform two actions:
# 1. I separate orbits extracted from each cell lines and put them together.
# in such way, orbit 0 of the cells will be in a file, orbits 1 will be i.
# in such way, separate file and so forth until the 72nd orbit.
#
# 2. I then run mine.jar on the files to extract the pairwise MIC values. As a result of this
# step, I will have pairwise MIC comparison between all cell lines for all orbitals of a
# certain chromosome.
#
# By repeating steps 1 and 2 for all 23 chromosomes, I will have pairwise MIC values for all
# orbitals of all cell lines. I woulb eventually be able to have a data array of shape
# ``` A(23 * 73) ```, where the rows correspond to the chromosomes and columns correspond
# to orbits.

# %%
import numpy as np
import cv2
from utility import *
import matplotlib.pyplot as plt
from iced import normalization
from iced import filter
import os
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/bzr0014/watson/scripts/virt/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['colors', 'log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# The following R-script reads graphlet files corresponding the a chromosome which
# are located under ```data/*.edges```. It then writes the resulting orbits into
# ```data/*.graphlets```.

# %%
for chr1 in range(1, 24):
    chr2 = chr1
    graphlets_mit = readMat('data/chr%02d_%02d_mit.graphlets'%(chr1, chr2), delimiter='\t')
    graphlets_all = readMat('data/chr%02d_%02d_all.graphlets'%(chr1, chr2), delimiter='\t')
    graphlets_rl = readMat('data/chr%02d_%02d_rl.graphlets'%(chr1, chr2), delimiter='\t')
    graphlets_call4 = readMat('data/chr%02d_%02d_call4.graphlets'%(chr1, chr2), delimiter='\t')
    graphlets = {'mit' : graphlets_mit
                , 'all' : graphlets_all
                , 'rl' : graphlets_rl
                , 'call4' : graphlets_call4}
    pair_orbits(graphlets, chr1)
# Out:
# shape of graphlet for chromosome 1 of cell rl:                 298 by 73
# shape of graphlet for chromosome 1 of cell call4:                 298 by 73
# shape of graphlet for chromosome 1 of cell all:                 298 by 73
# shape of graphlet for chromosome 1 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr01_orbit00.paired.csv
# data/chr01_orbit01.paired.csv
# data/chr01_orbit02.paired.csv
# data/chr01_orbit03.paired.csv
# data/chr01_orbit04.paired.csv
# data/chr01_orbit05.paired.csv
# data/chr01_orbit06.paired.csv
# data/chr01_orbit07.paired.csv
# data/chr01_orbit08.paired.csv
# data/chr01_orbit09.paired.csv
# data/chr01_orbit10.paired.csv
# data/chr01_orbit11.paired.csv
# data/chr01_orbit12.paired.csv
# data/chr01_orbit13.paired.csv
# data/chr01_orbit14.paired.csv
# data/chr01_orbit15.paired.csv
# data/chr01_orbit16.paired.csv
# data/chr01_orbit17.paired.csv
# data/chr01_orbit18.paired.csv
# data/chr01_orbit19.paired.csv
# data/chr01_orbit20.paired.csv
# data/chr01_orbit21.paired.csv
# data/chr01_orbit22.paired.csv
# data/chr01_orbit23.paired.csv
# data/chr01_orbit24.paired.csv
# data/chr01_orbit25.paired.csv
# data/chr01_orbit26.paired.csv
# data/chr01_orbit27.paired.csv
# data/chr01_orbit28.paired.csv
# data/chr01_orbit29.paired.csv
# data/chr01_orbit30.paired.csv
# data/chr01_orbit31.paired.csv
# data/chr01_orbit32.paired.csv
# data/chr01_orbit33.paired.csv
# data/chr01_orbit34.paired.csv
# data/chr01_orbit35.paired.csv
# data/chr01_orbit36.paired.csv
# data/chr01_orbit37.paired.csv
# data/chr01_orbit38.paired.csv
# data/chr01_orbit39.paired.csv
# data/chr01_orbit40.paired.csv
# data/chr01_orbit41.paired.csv
# data/chr01_orbit42.paired.csv
# data/chr01_orbit43.paired.csv
# data/chr01_orbit44.paired.csv
# data/chr01_orbit45.paired.csv
# data/chr01_orbit46.paired.csv
# data/chr01_orbit47.paired.csv
# data/chr01_orbit48.paired.csv
# data/chr01_orbit49.paired.csv
# data/chr01_orbit50.paired.csv
# data/chr01_orbit51.paired.csv
# data/chr01_orbit52.paired.csv
# data/chr01_orbit53.paired.csv
# data/chr01_orbit54.paired.csv
# data/chr01_orbit55.paired.csv
# data/chr01_orbit56.paired.csv
# data/chr01_orbit57.paired.csv
# data/chr01_orbit58.paired.csv
# data/chr01_orbit59.paired.csv
# data/chr01_orbit60.paired.csv
# data/chr01_orbit61.paired.csv
# data/chr01_orbit62.paired.csv
# data/chr01_orbit63.paired.csv
# data/chr01_orbit64.paired.csv
# data/chr01_orbit65.paired.csv
# data/chr01_orbit66.paired.csv
# data/chr01_orbit67.paired.csv
# data/chr01_orbit68.paired.csv
# data/chr01_orbit69.paired.csv
# data/chr01_orbit70.paired.csv
# data/chr01_orbit71.paired.csv
# data/chr01_orbit72.paired.csv
# shape of graphlet for chromosome 2 of cell rl:                 298 by 73
# shape of graphlet for chromosome 2 of cell call4:                 298 by 73
# shape of graphlet for chromosome 2 of cell all:                 298 by 73
# shape of graphlet for chromosome 2 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr02_orbit00.paired.csv
# data/chr02_orbit01.paired.csv
# data/chr02_orbit02.paired.csv
# data/chr02_orbit03.paired.csv
# data/chr02_orbit04.paired.csv
# data/chr02_orbit05.paired.csv
# data/chr02_orbit06.paired.csv
# data/chr02_orbit07.paired.csv
# data/chr02_orbit08.paired.csv
# data/chr02_orbit09.paired.csv
# data/chr02_orbit10.paired.csv
# data/chr02_orbit11.paired.csv
# data/chr02_orbit12.paired.csv
# data/chr02_orbit13.paired.csv
# data/chr02_orbit14.paired.csv
# data/chr02_orbit15.paired.csv
# data/chr02_orbit16.paired.csv
# data/chr02_orbit17.paired.csv
# data/chr02_orbit18.paired.csv
# data/chr02_orbit19.paired.csv
# data/chr02_orbit20.paired.csv
# data/chr02_orbit21.paired.csv
# data/chr02_orbit22.paired.csv
# data/chr02_orbit23.paired.csv
# data/chr02_orbit24.paired.csv
# data/chr02_orbit25.paired.csv
# data/chr02_orbit26.paired.csv
# data/chr02_orbit27.paired.csv
# data/chr02_orbit28.paired.csv
# data/chr02_orbit29.paired.csv
# data/chr02_orbit30.paired.csv
# data/chr02_orbit31.paired.csv
# data/chr02_orbit32.paired.csv
# data/chr02_orbit33.paired.csv
# data/chr02_orbit34.paired.csv
# data/chr02_orbit35.paired.csv
# data/chr02_orbit36.paired.csv
# data/chr02_orbit37.paired.csv
# data/chr02_orbit38.paired.csv
# data/chr02_orbit39.paired.csv
# data/chr02_orbit40.paired.csv
# data/chr02_orbit41.paired.csv
# data/chr02_orbit42.paired.csv
# data/chr02_orbit43.paired.csv
# data/chr02_orbit44.paired.csv
# data/chr02_orbit45.paired.csv
# data/chr02_orbit46.paired.csv
# data/chr02_orbit47.paired.csv
# data/chr02_orbit48.paired.csv
# data/chr02_orbit49.paired.csv
# data/chr02_orbit50.paired.csv
# data/chr02_orbit51.paired.csv
# data/chr02_orbit52.paired.csv
# data/chr02_orbit53.paired.csv
# data/chr02_orbit54.paired.csv
# data/chr02_orbit55.paired.csv
# data/chr02_orbit56.paired.csv
# data/chr02_orbit57.paired.csv
# data/chr02_orbit58.paired.csv
# data/chr02_orbit59.paired.csv
# data/chr02_orbit60.paired.csv
# data/chr02_orbit61.paired.csv
# data/chr02_orbit62.paired.csv
# data/chr02_orbit63.paired.csv
# data/chr02_orbit64.paired.csv
# data/chr02_orbit65.paired.csv
# data/chr02_orbit66.paired.csv
# data/chr02_orbit67.paired.csv
# data/chr02_orbit68.paired.csv
# data/chr02_orbit69.paired.csv
# data/chr02_orbit70.paired.csv
# data/chr02_orbit71.paired.csv
# data/chr02_orbit72.paired.csv
# shape of graphlet for chromosome 3 of cell rl:                 298 by 73
# shape of graphlet for chromosome 3 of cell call4:                 298 by 73
# shape of graphlet for chromosome 3 of cell all:                 298 by 73
# shape of graphlet for chromosome 3 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr03_orbit00.paired.csv
# data/chr03_orbit01.paired.csv
# data/chr03_orbit02.paired.csv
# data/chr03_orbit03.paired.csv
# data/chr03_orbit04.paired.csv
# data/chr03_orbit05.paired.csv
# data/chr03_orbit06.paired.csv
# data/chr03_orbit07.paired.csv
# data/chr03_orbit08.paired.csv
# data/chr03_orbit09.paired.csv
# data/chr03_orbit10.paired.csv
# data/chr03_orbit11.paired.csv
# data/chr03_orbit12.paired.csv
# data/chr03_orbit13.paired.csv
# data/chr03_orbit14.paired.csv
# data/chr03_orbit15.paired.csv
# data/chr03_orbit16.paired.csv
# data/chr03_orbit17.paired.csv
# data/chr03_orbit18.paired.csv
# data/chr03_orbit19.paired.csv
# data/chr03_orbit20.paired.csv
# data/chr03_orbit21.paired.csv
# data/chr03_orbit22.paired.csv
# data/chr03_orbit23.paired.csv
# data/chr03_orbit24.paired.csv
# data/chr03_orbit25.paired.csv
# data/chr03_orbit26.paired.csv
# data/chr03_orbit27.paired.csv
# data/chr03_orbit28.paired.csv
# data/chr03_orbit29.paired.csv
# data/chr03_orbit30.paired.csv
# data/chr03_orbit31.paired.csv
# data/chr03_orbit32.paired.csv
# data/chr03_orbit33.paired.csv
# data/chr03_orbit34.paired.csv
# data/chr03_orbit35.paired.csv
# data/chr03_orbit36.paired.csv
# data/chr03_orbit37.paired.csv
# data/chr03_orbit38.paired.csv
# data/chr03_orbit39.paired.csv
# data/chr03_orbit40.paired.csv
# data/chr03_orbit41.paired.csv
# data/chr03_orbit42.paired.csv
# data/chr03_orbit43.paired.csv
# data/chr03_orbit44.paired.csv
# data/chr03_orbit45.paired.csv
# data/chr03_orbit46.paired.csv
# data/chr03_orbit47.paired.csv
# data/chr03_orbit48.paired.csv
# data/chr03_orbit49.paired.csv
# data/chr03_orbit50.paired.csv
# data/chr03_orbit51.paired.csv
# data/chr03_orbit52.paired.csv
# data/chr03_orbit53.paired.csv
# data/chr03_orbit54.paired.csv
# data/chr03_orbit55.paired.csv
# data/chr03_orbit56.paired.csv
# data/chr03_orbit57.paired.csv
# data/chr03_orbit58.paired.csv
# data/chr03_orbit59.paired.csv
# data/chr03_orbit60.paired.csv
# data/chr03_orbit61.paired.csv
# data/chr03_orbit62.paired.csv
# data/chr03_orbit63.paired.csv
# data/chr03_orbit64.paired.csv
# data/chr03_orbit65.paired.csv
# data/chr03_orbit66.paired.csv
# data/chr03_orbit67.paired.csv
# data/chr03_orbit68.paired.csv
# data/chr03_orbit69.paired.csv
# data/chr03_orbit70.paired.csv
# data/chr03_orbit71.paired.csv
# data/chr03_orbit72.paired.csv
# shape of graphlet for chromosome 4 of cell rl:                 298 by 73
# shape of graphlet for chromosome 4 of cell call4:                 298 by 73
# shape of graphlet for chromosome 4 of cell all:                 298 by 73
# shape of graphlet for chromosome 4 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr04_orbit00.paired.csv
# data/chr04_orbit01.paired.csv
# data/chr04_orbit02.paired.csv
# data/chr04_orbit03.paired.csv
# data/chr04_orbit04.paired.csv
# data/chr04_orbit05.paired.csv
# data/chr04_orbit06.paired.csv
# data/chr04_orbit07.paired.csv
# data/chr04_orbit08.paired.csv
# data/chr04_orbit09.paired.csv
# data/chr04_orbit10.paired.csv
# data/chr04_orbit11.paired.csv
# data/chr04_orbit12.paired.csv
# data/chr04_orbit13.paired.csv
# data/chr04_orbit14.paired.csv
# data/chr04_orbit15.paired.csv
# data/chr04_orbit16.paired.csv
# data/chr04_orbit17.paired.csv
# data/chr04_orbit18.paired.csv
# data/chr04_orbit19.paired.csv
# data/chr04_orbit20.paired.csv
# data/chr04_orbit21.paired.csv
# data/chr04_orbit22.paired.csv
# data/chr04_orbit23.paired.csv
# data/chr04_orbit24.paired.csv
# data/chr04_orbit25.paired.csv
# data/chr04_orbit26.paired.csv
# data/chr04_orbit27.paired.csv
# data/chr04_orbit28.paired.csv
# data/chr04_orbit29.paired.csv
# data/chr04_orbit30.paired.csv
# data/chr04_orbit31.paired.csv
# data/chr04_orbit32.paired.csv
# data/chr04_orbit33.paired.csv
# data/chr04_orbit34.paired.csv
# data/chr04_orbit35.paired.csv
# data/chr04_orbit36.paired.csv
# data/chr04_orbit37.paired.csv
# data/chr04_orbit38.paired.csv
# data/chr04_orbit39.paired.csv
# data/chr04_orbit40.paired.csv
# data/chr04_orbit41.paired.csv
# data/chr04_orbit42.paired.csv
# data/chr04_orbit43.paired.csv
# data/chr04_orbit44.paired.csv
# data/chr04_orbit45.paired.csv
# data/chr04_orbit46.paired.csv
# data/chr04_orbit47.paired.csv
# data/chr04_orbit48.paired.csv
# data/chr04_orbit49.paired.csv
# data/chr04_orbit50.paired.csv
# data/chr04_orbit51.paired.csv
# data/chr04_orbit52.paired.csv
# data/chr04_orbit53.paired.csv
# data/chr04_orbit54.paired.csv
# data/chr04_orbit55.paired.csv
# data/chr04_orbit56.paired.csv
# data/chr04_orbit57.paired.csv
# data/chr04_orbit58.paired.csv
# data/chr04_orbit59.paired.csv
# data/chr04_orbit60.paired.csv
# data/chr04_orbit61.paired.csv
# data/chr04_orbit62.paired.csv
# data/chr04_orbit63.paired.csv
# data/chr04_orbit64.paired.csv
# data/chr04_orbit65.paired.csv
# data/chr04_orbit66.paired.csv
# data/chr04_orbit67.paired.csv
# data/chr04_orbit68.paired.csv
# data/chr04_orbit69.paired.csv
# data/chr04_orbit70.paired.csv
# data/chr04_orbit71.paired.csv
# data/chr04_orbit72.paired.csv
# shape of graphlet for chromosome 5 of cell rl:                 298 by 73
# shape of graphlet for chromosome 5 of cell call4:                 298 by 73
# shape of graphlet for chromosome 5 of cell all:                 298 by 73
# shape of graphlet for chromosome 5 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr05_orbit00.paired.csv
# data/chr05_orbit01.paired.csv
# data/chr05_orbit02.paired.csv
# data/chr05_orbit03.paired.csv
# data/chr05_orbit04.paired.csv
# data/chr05_orbit05.paired.csv
# data/chr05_orbit06.paired.csv
# data/chr05_orbit07.paired.csv
# data/chr05_orbit08.paired.csv
# data/chr05_orbit09.paired.csv
# data/chr05_orbit10.paired.csv
# data/chr05_orbit11.paired.csv
# data/chr05_orbit12.paired.csv
# data/chr05_orbit13.paired.csv
# data/chr05_orbit14.paired.csv
# data/chr05_orbit15.paired.csv
# data/chr05_orbit16.paired.csv
# data/chr05_orbit17.paired.csv
# data/chr05_orbit18.paired.csv
# data/chr05_orbit19.paired.csv
# data/chr05_orbit20.paired.csv
# data/chr05_orbit21.paired.csv
# data/chr05_orbit22.paired.csv
# data/chr05_orbit23.paired.csv
# data/chr05_orbit24.paired.csv
# data/chr05_orbit25.paired.csv
# data/chr05_orbit26.paired.csv
# data/chr05_orbit27.paired.csv
# data/chr05_orbit28.paired.csv
# data/chr05_orbit29.paired.csv
# data/chr05_orbit30.paired.csv
# data/chr05_orbit31.paired.csv
# data/chr05_orbit32.paired.csv
# data/chr05_orbit33.paired.csv
# data/chr05_orbit34.paired.csv
# data/chr05_orbit35.paired.csv
# data/chr05_orbit36.paired.csv
# data/chr05_orbit37.paired.csv
# data/chr05_orbit38.paired.csv
# data/chr05_orbit39.paired.csv
# data/chr05_orbit40.paired.csv
# data/chr05_orbit41.paired.csv
# data/chr05_orbit42.paired.csv
# data/chr05_orbit43.paired.csv
# data/chr05_orbit44.paired.csv
# data/chr05_orbit45.paired.csv
# data/chr05_orbit46.paired.csv
# data/chr05_orbit47.paired.csv
# data/chr05_orbit48.paired.csv
# data/chr05_orbit49.paired.csv
# data/chr05_orbit50.paired.csv
# data/chr05_orbit51.paired.csv
# data/chr05_orbit52.paired.csv
# data/chr05_orbit53.paired.csv
# data/chr05_orbit54.paired.csv
# data/chr05_orbit55.paired.csv
# data/chr05_orbit56.paired.csv
# data/chr05_orbit57.paired.csv
# data/chr05_orbit58.paired.csv
# data/chr05_orbit59.paired.csv
# data/chr05_orbit60.paired.csv
# data/chr05_orbit61.paired.csv
# data/chr05_orbit62.paired.csv
# data/chr05_orbit63.paired.csv
# data/chr05_orbit64.paired.csv
# data/chr05_orbit65.paired.csv
# data/chr05_orbit66.paired.csv
# data/chr05_orbit67.paired.csv
# data/chr05_orbit68.paired.csv
# data/chr05_orbit69.paired.csv
# data/chr05_orbit70.paired.csv
# data/chr05_orbit71.paired.csv
# data/chr05_orbit72.paired.csv
# shape of graphlet for chromosome 6 of cell rl:                 298 by 73
# shape of graphlet for chromosome 6 of cell call4:                 298 by 73
# shape of graphlet for chromosome 6 of cell all:                 298 by 73
# shape of graphlet for chromosome 6 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr06_orbit00.paired.csv
# data/chr06_orbit01.paired.csv
# data/chr06_orbit02.paired.csv
# data/chr06_orbit03.paired.csv
# data/chr06_orbit04.paired.csv
# data/chr06_orbit05.paired.csv
# data/chr06_orbit06.paired.csv
# data/chr06_orbit07.paired.csv
# data/chr06_orbit08.paired.csv
# data/chr06_orbit09.paired.csv
# data/chr06_orbit10.paired.csv
# data/chr06_orbit11.paired.csv
# data/chr06_orbit12.paired.csv
# data/chr06_orbit13.paired.csv
# data/chr06_orbit14.paired.csv
# data/chr06_orbit15.paired.csv
# data/chr06_orbit16.paired.csv
# data/chr06_orbit17.paired.csv
# data/chr06_orbit18.paired.csv
# data/chr06_orbit19.paired.csv
# data/chr06_orbit20.paired.csv
# data/chr06_orbit21.paired.csv
# data/chr06_orbit22.paired.csv
# data/chr06_orbit23.paired.csv
# data/chr06_orbit24.paired.csv
# data/chr06_orbit25.paired.csv
# data/chr06_orbit26.paired.csv
# data/chr06_orbit27.paired.csv
# data/chr06_orbit28.paired.csv
# data/chr06_orbit29.paired.csv
# data/chr06_orbit30.paired.csv
# data/chr06_orbit31.paired.csv
# data/chr06_orbit32.paired.csv
# data/chr06_orbit33.paired.csv
# data/chr06_orbit34.paired.csv
# data/chr06_orbit35.paired.csv
# data/chr06_orbit36.paired.csv
# data/chr06_orbit37.paired.csv
# data/chr06_orbit38.paired.csv
# data/chr06_orbit39.paired.csv
# data/chr06_orbit40.paired.csv
# data/chr06_orbit41.paired.csv
# data/chr06_orbit42.paired.csv
# data/chr06_orbit43.paired.csv
# data/chr06_orbit44.paired.csv
# data/chr06_orbit45.paired.csv
# data/chr06_orbit46.paired.csv
# data/chr06_orbit47.paired.csv
# data/chr06_orbit48.paired.csv
# data/chr06_orbit49.paired.csv
# data/chr06_orbit50.paired.csv
# data/chr06_orbit51.paired.csv
# data/chr06_orbit52.paired.csv
# data/chr06_orbit53.paired.csv
# data/chr06_orbit54.paired.csv
# data/chr06_orbit55.paired.csv
# data/chr06_orbit56.paired.csv
# data/chr06_orbit57.paired.csv
# data/chr06_orbit58.paired.csv
# data/chr06_orbit59.paired.csv
# data/chr06_orbit60.paired.csv
# data/chr06_orbit61.paired.csv
# data/chr06_orbit62.paired.csv
# data/chr06_orbit63.paired.csv
# data/chr06_orbit64.paired.csv
# data/chr06_orbit65.paired.csv
# data/chr06_orbit66.paired.csv
# data/chr06_orbit67.paired.csv
# data/chr06_orbit68.paired.csv
# data/chr06_orbit69.paired.csv
# data/chr06_orbit70.paired.csv
# data/chr06_orbit71.paired.csv
# data/chr06_orbit72.paired.csv
# shape of graphlet for chromosome 7 of cell rl:                 298 by 73
# shape of graphlet for chromosome 7 of cell call4:                 298 by 73
# shape of graphlet for chromosome 7 of cell all:                 298 by 73
# shape of graphlet for chromosome 7 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr07_orbit00.paired.csv
# data/chr07_orbit01.paired.csv
# data/chr07_orbit02.paired.csv
# data/chr07_orbit03.paired.csv
# data/chr07_orbit04.paired.csv
# data/chr07_orbit05.paired.csv
# data/chr07_orbit06.paired.csv
# data/chr07_orbit07.paired.csv
# data/chr07_orbit08.paired.csv
# data/chr07_orbit09.paired.csv
# data/chr07_orbit10.paired.csv
# data/chr07_orbit11.paired.csv
# data/chr07_orbit12.paired.csv
# data/chr07_orbit13.paired.csv
# data/chr07_orbit14.paired.csv
# data/chr07_orbit15.paired.csv
# data/chr07_orbit16.paired.csv
# data/chr07_orbit17.paired.csv
# data/chr07_orbit18.paired.csv
# data/chr07_orbit19.paired.csv
# data/chr07_orbit20.paired.csv
# data/chr07_orbit21.paired.csv
# data/chr07_orbit22.paired.csv
# data/chr07_orbit23.paired.csv
# data/chr07_orbit24.paired.csv
# data/chr07_orbit25.paired.csv
# data/chr07_orbit26.paired.csv
# data/chr07_orbit27.paired.csv
# data/chr07_orbit28.paired.csv
# data/chr07_orbit29.paired.csv
# data/chr07_orbit30.paired.csv
# data/chr07_orbit31.paired.csv
# data/chr07_orbit32.paired.csv
# data/chr07_orbit33.paired.csv
# data/chr07_orbit34.paired.csv
# data/chr07_orbit35.paired.csv
# data/chr07_orbit36.paired.csv
# data/chr07_orbit37.paired.csv
# data/chr07_orbit38.paired.csv
# data/chr07_orbit39.paired.csv
# data/chr07_orbit40.paired.csv
# data/chr07_orbit41.paired.csv
# data/chr07_orbit42.paired.csv
# data/chr07_orbit43.paired.csv
# data/chr07_orbit44.paired.csv
# data/chr07_orbit45.paired.csv
# data/chr07_orbit46.paired.csv
# data/chr07_orbit47.paired.csv
# data/chr07_orbit48.paired.csv
# data/chr07_orbit49.paired.csv
# data/chr07_orbit50.paired.csv
# data/chr07_orbit51.paired.csv
# data/chr07_orbit52.paired.csv
# data/chr07_orbit53.paired.csv
# data/chr07_orbit54.paired.csv
# data/chr07_orbit55.paired.csv
# data/chr07_orbit56.paired.csv
# data/chr07_orbit57.paired.csv
# data/chr07_orbit58.paired.csv
# data/chr07_orbit59.paired.csv
# data/chr07_orbit60.paired.csv
# data/chr07_orbit61.paired.csv
# data/chr07_orbit62.paired.csv
# data/chr07_orbit63.paired.csv
# data/chr07_orbit64.paired.csv
# data/chr07_orbit65.paired.csv
# data/chr07_orbit66.paired.csv
# data/chr07_orbit67.paired.csv
# data/chr07_orbit68.paired.csv
# data/chr07_orbit69.paired.csv
# data/chr07_orbit70.paired.csv
# data/chr07_orbit71.paired.csv
# data/chr07_orbit72.paired.csv
# shape of graphlet for chromosome 8 of cell rl:                 298 by 73
# shape of graphlet for chromosome 8 of cell call4:                 298 by 73
# shape of graphlet for chromosome 8 of cell all:                 298 by 73
# shape of graphlet for chromosome 8 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr08_orbit00.paired.csv
# data/chr08_orbit01.paired.csv
# data/chr08_orbit02.paired.csv
# data/chr08_orbit03.paired.csv
# data/chr08_orbit04.paired.csv
# data/chr08_orbit05.paired.csv
# data/chr08_orbit06.paired.csv
# data/chr08_orbit07.paired.csv
# data/chr08_orbit08.paired.csv
# data/chr08_orbit09.paired.csv
# data/chr08_orbit10.paired.csv
# data/chr08_orbit11.paired.csv
# data/chr08_orbit12.paired.csv
# data/chr08_orbit13.paired.csv
# data/chr08_orbit14.paired.csv
# data/chr08_orbit15.paired.csv
# data/chr08_orbit16.paired.csv
# data/chr08_orbit17.paired.csv
# data/chr08_orbit18.paired.csv
# data/chr08_orbit19.paired.csv
# data/chr08_orbit20.paired.csv
# data/chr08_orbit21.paired.csv
# data/chr08_orbit22.paired.csv
# data/chr08_orbit23.paired.csv
# data/chr08_orbit24.paired.csv
# data/chr08_orbit25.paired.csv
# data/chr08_orbit26.paired.csv
# data/chr08_orbit27.paired.csv
# data/chr08_orbit28.paired.csv
# data/chr08_orbit29.paired.csv
# data/chr08_orbit30.paired.csv
# data/chr08_orbit31.paired.csv
# data/chr08_orbit32.paired.csv
# data/chr08_orbit33.paired.csv
# data/chr08_orbit34.paired.csv
# data/chr08_orbit35.paired.csv
# data/chr08_orbit36.paired.csv
# data/chr08_orbit37.paired.csv
# data/chr08_orbit38.paired.csv
# data/chr08_orbit39.paired.csv
# data/chr08_orbit40.paired.csv
# data/chr08_orbit41.paired.csv
# data/chr08_orbit42.paired.csv
# data/chr08_orbit43.paired.csv
# data/chr08_orbit44.paired.csv
# data/chr08_orbit45.paired.csv
# data/chr08_orbit46.paired.csv
# data/chr08_orbit47.paired.csv
# data/chr08_orbit48.paired.csv
# data/chr08_orbit49.paired.csv
# data/chr08_orbit50.paired.csv
# data/chr08_orbit51.paired.csv
# data/chr08_orbit52.paired.csv
# data/chr08_orbit53.paired.csv
# data/chr08_orbit54.paired.csv
# data/chr08_orbit55.paired.csv
# data/chr08_orbit56.paired.csv
# data/chr08_orbit57.paired.csv
# data/chr08_orbit58.paired.csv
# data/chr08_orbit59.paired.csv
# data/chr08_orbit60.paired.csv
# data/chr08_orbit61.paired.csv
# data/chr08_orbit62.paired.csv
# data/chr08_orbit63.paired.csv
# data/chr08_orbit64.paired.csv
# data/chr08_orbit65.paired.csv
# data/chr08_orbit66.paired.csv
# data/chr08_orbit67.paired.csv
# data/chr08_orbit68.paired.csv
# data/chr08_orbit69.paired.csv
# data/chr08_orbit70.paired.csv
# data/chr08_orbit71.paired.csv
# data/chr08_orbit72.paired.csv
# shape of graphlet for chromosome 9 of cell rl:                 298 by 73
# shape of graphlet for chromosome 9 of cell call4:                 298 by 73
# shape of graphlet for chromosome 9 of cell all:                 298 by 73
# shape of graphlet for chromosome 9 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr09_orbit00.paired.csv
# data/chr09_orbit01.paired.csv
# data/chr09_orbit02.paired.csv
# data/chr09_orbit03.paired.csv
# data/chr09_orbit04.paired.csv
# data/chr09_orbit05.paired.csv
# data/chr09_orbit06.paired.csv
# data/chr09_orbit07.paired.csv
# data/chr09_orbit08.paired.csv
# data/chr09_orbit09.paired.csv
# data/chr09_orbit10.paired.csv
# data/chr09_orbit11.paired.csv
# data/chr09_orbit12.paired.csv
# data/chr09_orbit13.paired.csv
# data/chr09_orbit14.paired.csv
# data/chr09_orbit15.paired.csv
# data/chr09_orbit16.paired.csv
# data/chr09_orbit17.paired.csv
# data/chr09_orbit18.paired.csv
# data/chr09_orbit19.paired.csv
# data/chr09_orbit20.paired.csv
# data/chr09_orbit21.paired.csv
# data/chr09_orbit22.paired.csv
# data/chr09_orbit23.paired.csv
# data/chr09_orbit24.paired.csv
# data/chr09_orbit25.paired.csv
# data/chr09_orbit26.paired.csv
# data/chr09_orbit27.paired.csv
# data/chr09_orbit28.paired.csv
# data/chr09_orbit29.paired.csv
# data/chr09_orbit30.paired.csv
# data/chr09_orbit31.paired.csv
# data/chr09_orbit32.paired.csv
# data/chr09_orbit33.paired.csv
# data/chr09_orbit34.paired.csv
# data/chr09_orbit35.paired.csv
# data/chr09_orbit36.paired.csv
# data/chr09_orbit37.paired.csv
# data/chr09_orbit38.paired.csv
# data/chr09_orbit39.paired.csv
# data/chr09_orbit40.paired.csv
# data/chr09_orbit41.paired.csv
# data/chr09_orbit42.paired.csv
# data/chr09_orbit43.paired.csv
# data/chr09_orbit44.paired.csv
# data/chr09_orbit45.paired.csv
# data/chr09_orbit46.paired.csv
# data/chr09_orbit47.paired.csv
# data/chr09_orbit48.paired.csv
# data/chr09_orbit49.paired.csv
# data/chr09_orbit50.paired.csv
# data/chr09_orbit51.paired.csv
# data/chr09_orbit52.paired.csv
# data/chr09_orbit53.paired.csv
# data/chr09_orbit54.paired.csv
# data/chr09_orbit55.paired.csv
# data/chr09_orbit56.paired.csv
# data/chr09_orbit57.paired.csv
# data/chr09_orbit58.paired.csv
# data/chr09_orbit59.paired.csv
# data/chr09_orbit60.paired.csv
# data/chr09_orbit61.paired.csv
# data/chr09_orbit62.paired.csv
# data/chr09_orbit63.paired.csv
# data/chr09_orbit64.paired.csv
# data/chr09_orbit65.paired.csv
# data/chr09_orbit66.paired.csv
# data/chr09_orbit67.paired.csv
# data/chr09_orbit68.paired.csv
# data/chr09_orbit69.paired.csv
# data/chr09_orbit70.paired.csv
# data/chr09_orbit71.paired.csv
# data/chr09_orbit72.paired.csv
# shape of graphlet for chromosome 10 of cell rl:                 298 by 73
# shape of graphlet for chromosome 10 of cell call4:                 298 by 73
# shape of graphlet for chromosome 10 of cell all:                 298 by 73
# shape of graphlet for chromosome 10 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr10_orbit00.paired.csv
# data/chr10_orbit01.paired.csv
# data/chr10_orbit02.paired.csv
# data/chr10_orbit03.paired.csv
# data/chr10_orbit04.paired.csv
# data/chr10_orbit05.paired.csv
# data/chr10_orbit06.paired.csv
# data/chr10_orbit07.paired.csv
# data/chr10_orbit08.paired.csv
# data/chr10_orbit09.paired.csv
# data/chr10_orbit10.paired.csv
# data/chr10_orbit11.paired.csv
# data/chr10_orbit12.paired.csv
# data/chr10_orbit13.paired.csv
# data/chr10_orbit14.paired.csv
# data/chr10_orbit15.paired.csv
# data/chr10_orbit16.paired.csv
# data/chr10_orbit17.paired.csv
# data/chr10_orbit18.paired.csv
# data/chr10_orbit19.paired.csv
# data/chr10_orbit20.paired.csv
# data/chr10_orbit21.paired.csv
# data/chr10_orbit22.paired.csv
# data/chr10_orbit23.paired.csv
# data/chr10_orbit24.paired.csv
# data/chr10_orbit25.paired.csv
# data/chr10_orbit26.paired.csv
# data/chr10_orbit27.paired.csv
# data/chr10_orbit28.paired.csv
# data/chr10_orbit29.paired.csv
# data/chr10_orbit30.paired.csv
# data/chr10_orbit31.paired.csv
# data/chr10_orbit32.paired.csv
# data/chr10_orbit33.paired.csv
# data/chr10_orbit34.paired.csv
# data/chr10_orbit35.paired.csv
# data/chr10_orbit36.paired.csv
# data/chr10_orbit37.paired.csv
# data/chr10_orbit38.paired.csv
# data/chr10_orbit39.paired.csv
# data/chr10_orbit40.paired.csv
# data/chr10_orbit41.paired.csv
# data/chr10_orbit42.paired.csv
# data/chr10_orbit43.paired.csv
# data/chr10_orbit44.paired.csv
# data/chr10_orbit45.paired.csv
# data/chr10_orbit46.paired.csv
# data/chr10_orbit47.paired.csv
# data/chr10_orbit48.paired.csv
# data/chr10_orbit49.paired.csv
# data/chr10_orbit50.paired.csv
# data/chr10_orbit51.paired.csv
# data/chr10_orbit52.paired.csv
# data/chr10_orbit53.paired.csv
# data/chr10_orbit54.paired.csv
# data/chr10_orbit55.paired.csv
# data/chr10_orbit56.paired.csv
# data/chr10_orbit57.paired.csv
# data/chr10_orbit58.paired.csv
# data/chr10_orbit59.paired.csv
# data/chr10_orbit60.paired.csv
# data/chr10_orbit61.paired.csv
# data/chr10_orbit62.paired.csv
# data/chr10_orbit63.paired.csv
# data/chr10_orbit64.paired.csv
# data/chr10_orbit65.paired.csv
# data/chr10_orbit66.paired.csv
# data/chr10_orbit67.paired.csv
# data/chr10_orbit68.paired.csv
# data/chr10_orbit69.paired.csv
# data/chr10_orbit70.paired.csv
# data/chr10_orbit71.paired.csv
# data/chr10_orbit72.paired.csv
# shape of graphlet for chromosome 11 of cell rl:                 298 by 73
# shape of graphlet for chromosome 11 of cell call4:                 298 by 73
# shape of graphlet for chromosome 11 of cell all:                 298 by 73
# shape of graphlet for chromosome 11 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr11_orbit00.paired.csv
# data/chr11_orbit01.paired.csv
# data/chr11_orbit02.paired.csv
# data/chr11_orbit03.paired.csv
# data/chr11_orbit04.paired.csv
# data/chr11_orbit05.paired.csv
# data/chr11_orbit06.paired.csv
# data/chr11_orbit07.paired.csv
# data/chr11_orbit08.paired.csv
# data/chr11_orbit09.paired.csv
# data/chr11_orbit10.paired.csv
# data/chr11_orbit11.paired.csv
# data/chr11_orbit12.paired.csv
# data/chr11_orbit13.paired.csv
# data/chr11_orbit14.paired.csv
# data/chr11_orbit15.paired.csv
# data/chr11_orbit16.paired.csv
# data/chr11_orbit17.paired.csv
# data/chr11_orbit18.paired.csv
# data/chr11_orbit19.paired.csv
# data/chr11_orbit20.paired.csv
# data/chr11_orbit21.paired.csv
# data/chr11_orbit22.paired.csv
# data/chr11_orbit23.paired.csv
# data/chr11_orbit24.paired.csv
# data/chr11_orbit25.paired.csv
# data/chr11_orbit26.paired.csv
# data/chr11_orbit27.paired.csv
# data/chr11_orbit28.paired.csv
# data/chr11_orbit29.paired.csv
# data/chr11_orbit30.paired.csv
# data/chr11_orbit31.paired.csv
# data/chr11_orbit32.paired.csv
# data/chr11_orbit33.paired.csv
# data/chr11_orbit34.paired.csv
# data/chr11_orbit35.paired.csv
# data/chr11_orbit36.paired.csv
# data/chr11_orbit37.paired.csv
# data/chr11_orbit38.paired.csv
# data/chr11_orbit39.paired.csv
# data/chr11_orbit40.paired.csv
# data/chr11_orbit41.paired.csv
# data/chr11_orbit42.paired.csv
# data/chr11_orbit43.paired.csv
# data/chr11_orbit44.paired.csv
# data/chr11_orbit45.paired.csv
# data/chr11_orbit46.paired.csv
# data/chr11_orbit47.paired.csv
# data/chr11_orbit48.paired.csv
# data/chr11_orbit49.paired.csv
# data/chr11_orbit50.paired.csv
# data/chr11_orbit51.paired.csv
# data/chr11_orbit52.paired.csv
# data/chr11_orbit53.paired.csv
# data/chr11_orbit54.paired.csv
# data/chr11_orbit55.paired.csv
# data/chr11_orbit56.paired.csv
# data/chr11_orbit57.paired.csv
# data/chr11_orbit58.paired.csv
# data/chr11_orbit59.paired.csv
# data/chr11_orbit60.paired.csv
# data/chr11_orbit61.paired.csv
# data/chr11_orbit62.paired.csv
# data/chr11_orbit63.paired.csv
# data/chr11_orbit64.paired.csv
# data/chr11_orbit65.paired.csv
# data/chr11_orbit66.paired.csv
# data/chr11_orbit67.paired.csv
# data/chr11_orbit68.paired.csv
# data/chr11_orbit69.paired.csv
# data/chr11_orbit70.paired.csv
# data/chr11_orbit71.paired.csv
# data/chr11_orbit72.paired.csv
# shape of graphlet for chromosome 12 of cell rl:                 298 by 73
# shape of graphlet for chromosome 12 of cell call4:                 298 by 73
# shape of graphlet for chromosome 12 of cell all:                 298 by 73
# shape of graphlet for chromosome 12 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr12_orbit00.paired.csv
# data/chr12_orbit01.paired.csv
# data/chr12_orbit02.paired.csv
# data/chr12_orbit03.paired.csv
# data/chr12_orbit04.paired.csv
# data/chr12_orbit05.paired.csv
# data/chr12_orbit06.paired.csv
# data/chr12_orbit07.paired.csv
# data/chr12_orbit08.paired.csv
# data/chr12_orbit09.paired.csv
# data/chr12_orbit10.paired.csv
# data/chr12_orbit11.paired.csv
# data/chr12_orbit12.paired.csv
# data/chr12_orbit13.paired.csv
# data/chr12_orbit14.paired.csv
# data/chr12_orbit15.paired.csv
# data/chr12_orbit16.paired.csv
# data/chr12_orbit17.paired.csv
# data/chr12_orbit18.paired.csv
# data/chr12_orbit19.paired.csv
# data/chr12_orbit20.paired.csv
# data/chr12_orbit21.paired.csv
# data/chr12_orbit22.paired.csv
# data/chr12_orbit23.paired.csv
# data/chr12_orbit24.paired.csv
# data/chr12_orbit25.paired.csv
# data/chr12_orbit26.paired.csv
# data/chr12_orbit27.paired.csv
# data/chr12_orbit28.paired.csv
# data/chr12_orbit29.paired.csv
# data/chr12_orbit30.paired.csv
# data/chr12_orbit31.paired.csv
# data/chr12_orbit32.paired.csv
# data/chr12_orbit33.paired.csv
# data/chr12_orbit34.paired.csv
# data/chr12_orbit35.paired.csv
# data/chr12_orbit36.paired.csv
# data/chr12_orbit37.paired.csv
# data/chr12_orbit38.paired.csv
# data/chr12_orbit39.paired.csv
# data/chr12_orbit40.paired.csv
# data/chr12_orbit41.paired.csv
# data/chr12_orbit42.paired.csv
# data/chr12_orbit43.paired.csv
# data/chr12_orbit44.paired.csv
# data/chr12_orbit45.paired.csv
# data/chr12_orbit46.paired.csv
# data/chr12_orbit47.paired.csv
# data/chr12_orbit48.paired.csv
# data/chr12_orbit49.paired.csv
# data/chr12_orbit50.paired.csv
# data/chr12_orbit51.paired.csv
# data/chr12_orbit52.paired.csv
# data/chr12_orbit53.paired.csv
# data/chr12_orbit54.paired.csv
# data/chr12_orbit55.paired.csv
# data/chr12_orbit56.paired.csv
# data/chr12_orbit57.paired.csv
# data/chr12_orbit58.paired.csv
# data/chr12_orbit59.paired.csv
# data/chr12_orbit60.paired.csv
# data/chr12_orbit61.paired.csv
# data/chr12_orbit62.paired.csv
# data/chr12_orbit63.paired.csv
# data/chr12_orbit64.paired.csv
# data/chr12_orbit65.paired.csv
# data/chr12_orbit66.paired.csv
# data/chr12_orbit67.paired.csv
# data/chr12_orbit68.paired.csv
# data/chr12_orbit69.paired.csv
# data/chr12_orbit70.paired.csv
# data/chr12_orbit71.paired.csv
# data/chr12_orbit72.paired.csv
# shape of graphlet for chromosome 13 of cell rl:                 298 by 73
# shape of graphlet for chromosome 13 of cell call4:                 298 by 73
# shape of graphlet for chromosome 13 of cell all:                 298 by 73
# shape of graphlet for chromosome 13 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr13_orbit00.paired.csv
# data/chr13_orbit01.paired.csv
# data/chr13_orbit02.paired.csv
# data/chr13_orbit03.paired.csv
# data/chr13_orbit04.paired.csv
# data/chr13_orbit05.paired.csv
# data/chr13_orbit06.paired.csv
# data/chr13_orbit07.paired.csv
# data/chr13_orbit08.paired.csv
# data/chr13_orbit09.paired.csv
# data/chr13_orbit10.paired.csv
# data/chr13_orbit11.paired.csv
# data/chr13_orbit12.paired.csv
# data/chr13_orbit13.paired.csv
# data/chr13_orbit14.paired.csv
# data/chr13_orbit15.paired.csv
# data/chr13_orbit16.paired.csv
# data/chr13_orbit17.paired.csv
# data/chr13_orbit18.paired.csv
# data/chr13_orbit19.paired.csv
# data/chr13_orbit20.paired.csv
# data/chr13_orbit21.paired.csv
# data/chr13_orbit22.paired.csv
# data/chr13_orbit23.paired.csv
# data/chr13_orbit24.paired.csv
# data/chr13_orbit25.paired.csv
# data/chr13_orbit26.paired.csv
# data/chr13_orbit27.paired.csv
# data/chr13_orbit28.paired.csv
# data/chr13_orbit29.paired.csv
# data/chr13_orbit30.paired.csv
# data/chr13_orbit31.paired.csv
# data/chr13_orbit32.paired.csv
# data/chr13_orbit33.paired.csv
# data/chr13_orbit34.paired.csv
# data/chr13_orbit35.paired.csv
# data/chr13_orbit36.paired.csv
# data/chr13_orbit37.paired.csv
# data/chr13_orbit38.paired.csv
# data/chr13_orbit39.paired.csv
# data/chr13_orbit40.paired.csv
# data/chr13_orbit41.paired.csv
# data/chr13_orbit42.paired.csv
# data/chr13_orbit43.paired.csv
# data/chr13_orbit44.paired.csv
# data/chr13_orbit45.paired.csv
# data/chr13_orbit46.paired.csv
# data/chr13_orbit47.paired.csv
# data/chr13_orbit48.paired.csv
# data/chr13_orbit49.paired.csv
# data/chr13_orbit50.paired.csv
# data/chr13_orbit51.paired.csv
# data/chr13_orbit52.paired.csv
# data/chr13_orbit53.paired.csv
# data/chr13_orbit54.paired.csv
# data/chr13_orbit55.paired.csv
# data/chr13_orbit56.paired.csv
# data/chr13_orbit57.paired.csv
# data/chr13_orbit58.paired.csv
# data/chr13_orbit59.paired.csv
# data/chr13_orbit60.paired.csv
# data/chr13_orbit61.paired.csv
# data/chr13_orbit62.paired.csv
# data/chr13_orbit63.paired.csv
# data/chr13_orbit64.paired.csv
# data/chr13_orbit65.paired.csv
# data/chr13_orbit66.paired.csv
# data/chr13_orbit67.paired.csv
# data/chr13_orbit68.paired.csv
# data/chr13_orbit69.paired.csv
# data/chr13_orbit70.paired.csv
# data/chr13_orbit71.paired.csv
# data/chr13_orbit72.paired.csv
# shape of graphlet for chromosome 14 of cell rl:                 298 by 73
# shape of graphlet for chromosome 14 of cell call4:                 298 by 73
# shape of graphlet for chromosome 14 of cell all:                 298 by 73
# shape of graphlet for chromosome 14 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr14_orbit00.paired.csv
# data/chr14_orbit01.paired.csv
# data/chr14_orbit02.paired.csv
# data/chr14_orbit03.paired.csv
# data/chr14_orbit04.paired.csv
# data/chr14_orbit05.paired.csv
# data/chr14_orbit06.paired.csv
# data/chr14_orbit07.paired.csv
# data/chr14_orbit08.paired.csv
# data/chr14_orbit09.paired.csv
# data/chr14_orbit10.paired.csv
# data/chr14_orbit11.paired.csv
# data/chr14_orbit12.paired.csv
# data/chr14_orbit13.paired.csv
# data/chr14_orbit14.paired.csv
# data/chr14_orbit15.paired.csv
# data/chr14_orbit16.paired.csv
# data/chr14_orbit17.paired.csv
# data/chr14_orbit18.paired.csv
# data/chr14_orbit19.paired.csv
# data/chr14_orbit20.paired.csv
# data/chr14_orbit21.paired.csv
# data/chr14_orbit22.paired.csv
# data/chr14_orbit23.paired.csv
# data/chr14_orbit24.paired.csv
# data/chr14_orbit25.paired.csv
# data/chr14_orbit26.paired.csv
# data/chr14_orbit27.paired.csv
# data/chr14_orbit28.paired.csv
# data/chr14_orbit29.paired.csv
# data/chr14_orbit30.paired.csv
# data/chr14_orbit31.paired.csv
# data/chr14_orbit32.paired.csv
# data/chr14_orbit33.paired.csv
# data/chr14_orbit34.paired.csv
# data/chr14_orbit35.paired.csv
# data/chr14_orbit36.paired.csv
# data/chr14_orbit37.paired.csv
# data/chr14_orbit38.paired.csv
# data/chr14_orbit39.paired.csv
# data/chr14_orbit40.paired.csv
# data/chr14_orbit41.paired.csv
# data/chr14_orbit42.paired.csv
# data/chr14_orbit43.paired.csv
# data/chr14_orbit44.paired.csv
# data/chr14_orbit45.paired.csv
# data/chr14_orbit46.paired.csv
# data/chr14_orbit47.paired.csv
# data/chr14_orbit48.paired.csv
# data/chr14_orbit49.paired.csv
# data/chr14_orbit50.paired.csv
# data/chr14_orbit51.paired.csv
# data/chr14_orbit52.paired.csv
# data/chr14_orbit53.paired.csv
# data/chr14_orbit54.paired.csv
# data/chr14_orbit55.paired.csv
# data/chr14_orbit56.paired.csv
# data/chr14_orbit57.paired.csv
# data/chr14_orbit58.paired.csv
# data/chr14_orbit59.paired.csv
# data/chr14_orbit60.paired.csv
# data/chr14_orbit61.paired.csv
# data/chr14_orbit62.paired.csv
# data/chr14_orbit63.paired.csv
# data/chr14_orbit64.paired.csv
# data/chr14_orbit65.paired.csv
# data/chr14_orbit66.paired.csv
# data/chr14_orbit67.paired.csv
# data/chr14_orbit68.paired.csv
# data/chr14_orbit69.paired.csv
# data/chr14_orbit70.paired.csv
# data/chr14_orbit71.paired.csv
# data/chr14_orbit72.paired.csv
# shape of graphlet for chromosome 15 of cell rl:                 298 by 73
# shape of graphlet for chromosome 15 of cell call4:                 298 by 73
# shape of graphlet for chromosome 15 of cell all:                 298 by 73
# shape of graphlet for chromosome 15 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr15_orbit00.paired.csv
# data/chr15_orbit01.paired.csv
# data/chr15_orbit02.paired.csv
# data/chr15_orbit03.paired.csv
# data/chr15_orbit04.paired.csv
# data/chr15_orbit05.paired.csv
# data/chr15_orbit06.paired.csv
# data/chr15_orbit07.paired.csv
# data/chr15_orbit08.paired.csv
# data/chr15_orbit09.paired.csv
# data/chr15_orbit10.paired.csv
# data/chr15_orbit11.paired.csv
# data/chr15_orbit12.paired.csv
# data/chr15_orbit13.paired.csv
# data/chr15_orbit14.paired.csv
# data/chr15_orbit15.paired.csv
# data/chr15_orbit16.paired.csv
# data/chr15_orbit17.paired.csv
# data/chr15_orbit18.paired.csv
# data/chr15_orbit19.paired.csv
# data/chr15_orbit20.paired.csv
# data/chr15_orbit21.paired.csv
# data/chr15_orbit22.paired.csv
# data/chr15_orbit23.paired.csv
# data/chr15_orbit24.paired.csv
# data/chr15_orbit25.paired.csv
# data/chr15_orbit26.paired.csv
# data/chr15_orbit27.paired.csv
# data/chr15_orbit28.paired.csv
# data/chr15_orbit29.paired.csv
# data/chr15_orbit30.paired.csv
# data/chr15_orbit31.paired.csv
# data/chr15_orbit32.paired.csv
# data/chr15_orbit33.paired.csv
# data/chr15_orbit34.paired.csv
# data/chr15_orbit35.paired.csv
# data/chr15_orbit36.paired.csv
# data/chr15_orbit37.paired.csv
# data/chr15_orbit38.paired.csv
# data/chr15_orbit39.paired.csv
# data/chr15_orbit40.paired.csv
# data/chr15_orbit41.paired.csv
# data/chr15_orbit42.paired.csv
# data/chr15_orbit43.paired.csv
# data/chr15_orbit44.paired.csv
# data/chr15_orbit45.paired.csv
# data/chr15_orbit46.paired.csv
# data/chr15_orbit47.paired.csv
# data/chr15_orbit48.paired.csv
# data/chr15_orbit49.paired.csv
# data/chr15_orbit50.paired.csv
# data/chr15_orbit51.paired.csv
# data/chr15_orbit52.paired.csv
# data/chr15_orbit53.paired.csv
# data/chr15_orbit54.paired.csv
# data/chr15_orbit55.paired.csv
# data/chr15_orbit56.paired.csv
# data/chr15_orbit57.paired.csv
# data/chr15_orbit58.paired.csv
# data/chr15_orbit59.paired.csv
# data/chr15_orbit60.paired.csv
# data/chr15_orbit61.paired.csv
# data/chr15_orbit62.paired.csv
# data/chr15_orbit63.paired.csv
# data/chr15_orbit64.paired.csv
# data/chr15_orbit65.paired.csv
# data/chr15_orbit66.paired.csv
# data/chr15_orbit67.paired.csv
# data/chr15_orbit68.paired.csv
# data/chr15_orbit69.paired.csv
# data/chr15_orbit70.paired.csv
# data/chr15_orbit71.paired.csv
# data/chr15_orbit72.paired.csv
# shape of graphlet for chromosome 16 of cell rl:                 298 by 73
# shape of graphlet for chromosome 16 of cell call4:                 298 by 73
# shape of graphlet for chromosome 16 of cell all:                 298 by 73
# shape of graphlet for chromosome 16 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr16_orbit00.paired.csv
# data/chr16_orbit01.paired.csv
# data/chr16_orbit02.paired.csv
# data/chr16_orbit03.paired.csv
# data/chr16_orbit04.paired.csv
# data/chr16_orbit05.paired.csv
# data/chr16_orbit06.paired.csv
# data/chr16_orbit07.paired.csv
# data/chr16_orbit08.paired.csv
# data/chr16_orbit09.paired.csv
# data/chr16_orbit10.paired.csv
# data/chr16_orbit11.paired.csv
# data/chr16_orbit12.paired.csv
# data/chr16_orbit13.paired.csv
# data/chr16_orbit14.paired.csv
# data/chr16_orbit15.paired.csv
# data/chr16_orbit16.paired.csv
# data/chr16_orbit17.paired.csv
# data/chr16_orbit18.paired.csv
# data/chr16_orbit19.paired.csv
# data/chr16_orbit20.paired.csv
# data/chr16_orbit21.paired.csv
# data/chr16_orbit22.paired.csv
# data/chr16_orbit23.paired.csv
# data/chr16_orbit24.paired.csv
# data/chr16_orbit25.paired.csv
# data/chr16_orbit26.paired.csv
# data/chr16_orbit27.paired.csv
# data/chr16_orbit28.paired.csv
# data/chr16_orbit29.paired.csv
# data/chr16_orbit30.paired.csv
# data/chr16_orbit31.paired.csv
# data/chr16_orbit32.paired.csv
# data/chr16_orbit33.paired.csv
# data/chr16_orbit34.paired.csv
# data/chr16_orbit35.paired.csv
# data/chr16_orbit36.paired.csv
# data/chr16_orbit37.paired.csv
# data/chr16_orbit38.paired.csv
# data/chr16_orbit39.paired.csv
# data/chr16_orbit40.paired.csv
# data/chr16_orbit41.paired.csv
# data/chr16_orbit42.paired.csv
# data/chr16_orbit43.paired.csv
# data/chr16_orbit44.paired.csv
# data/chr16_orbit45.paired.csv
# data/chr16_orbit46.paired.csv
# data/chr16_orbit47.paired.csv
# data/chr16_orbit48.paired.csv
# data/chr16_orbit49.paired.csv
# data/chr16_orbit50.paired.csv
# data/chr16_orbit51.paired.csv
# data/chr16_orbit52.paired.csv
# data/chr16_orbit53.paired.csv
# data/chr16_orbit54.paired.csv
# data/chr16_orbit55.paired.csv
# data/chr16_orbit56.paired.csv
# data/chr16_orbit57.paired.csv
# data/chr16_orbit58.paired.csv
# data/chr16_orbit59.paired.csv
# data/chr16_orbit60.paired.csv
# data/chr16_orbit61.paired.csv
# data/chr16_orbit62.paired.csv
# data/chr16_orbit63.paired.csv
# data/chr16_orbit64.paired.csv
# data/chr16_orbit65.paired.csv
# data/chr16_orbit66.paired.csv
# data/chr16_orbit67.paired.csv
# data/chr16_orbit68.paired.csv
# data/chr16_orbit69.paired.csv
# data/chr16_orbit70.paired.csv
# data/chr16_orbit71.paired.csv
# data/chr16_orbit72.paired.csv
# shape of graphlet for chromosome 17 of cell rl:                 298 by 73
# shape of graphlet for chromosome 17 of cell call4:                 298 by 73
# shape of graphlet for chromosome 17 of cell all:                 298 by 73
# shape of graphlet for chromosome 17 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr17_orbit00.paired.csv
# data/chr17_orbit01.paired.csv
# data/chr17_orbit02.paired.csv
# data/chr17_orbit03.paired.csv
# data/chr17_orbit04.paired.csv
# data/chr17_orbit05.paired.csv
# data/chr17_orbit06.paired.csv
# data/chr17_orbit07.paired.csv
# data/chr17_orbit08.paired.csv
# data/chr17_orbit09.paired.csv
# data/chr17_orbit10.paired.csv
# data/chr17_orbit11.paired.csv
# data/chr17_orbit12.paired.csv
# data/chr17_orbit13.paired.csv
# data/chr17_orbit14.paired.csv
# data/chr17_orbit15.paired.csv
# data/chr17_orbit16.paired.csv
# data/chr17_orbit17.paired.csv
# data/chr17_orbit18.paired.csv
# data/chr17_orbit19.paired.csv
# data/chr17_orbit20.paired.csv
# data/chr17_orbit21.paired.csv
# data/chr17_orbit22.paired.csv
# data/chr17_orbit23.paired.csv
# data/chr17_orbit24.paired.csv
# data/chr17_orbit25.paired.csv
# data/chr17_orbit26.paired.csv
# data/chr17_orbit27.paired.csv
# data/chr17_orbit28.paired.csv
# data/chr17_orbit29.paired.csv
# data/chr17_orbit30.paired.csv
# data/chr17_orbit31.paired.csv
# data/chr17_orbit32.paired.csv
# data/chr17_orbit33.paired.csv
# data/chr17_orbit34.paired.csv
# data/chr17_orbit35.paired.csv
# data/chr17_orbit36.paired.csv
# data/chr17_orbit37.paired.csv
# data/chr17_orbit38.paired.csv
# data/chr17_orbit39.paired.csv
# data/chr17_orbit40.paired.csv
# data/chr17_orbit41.paired.csv
# data/chr17_orbit42.paired.csv
# data/chr17_orbit43.paired.csv
# data/chr17_orbit44.paired.csv
# data/chr17_orbit45.paired.csv
# data/chr17_orbit46.paired.csv
# data/chr17_orbit47.paired.csv
# data/chr17_orbit48.paired.csv
# data/chr17_orbit49.paired.csv
# data/chr17_orbit50.paired.csv
# data/chr17_orbit51.paired.csv
# data/chr17_orbit52.paired.csv
# data/chr17_orbit53.paired.csv
# data/chr17_orbit54.paired.csv
# data/chr17_orbit55.paired.csv
# data/chr17_orbit56.paired.csv
# data/chr17_orbit57.paired.csv
# data/chr17_orbit58.paired.csv
# data/chr17_orbit59.paired.csv
# data/chr17_orbit60.paired.csv
# data/chr17_orbit61.paired.csv
# data/chr17_orbit62.paired.csv
# data/chr17_orbit63.paired.csv
# data/chr17_orbit64.paired.csv
# data/chr17_orbit65.paired.csv
# data/chr17_orbit66.paired.csv
# data/chr17_orbit67.paired.csv
# data/chr17_orbit68.paired.csv
# data/chr17_orbit69.paired.csv
# data/chr17_orbit70.paired.csv
# data/chr17_orbit71.paired.csv
# data/chr17_orbit72.paired.csv
# shape of graphlet for chromosome 18 of cell rl:                 298 by 73
# shape of graphlet for chromosome 18 of cell call4:                 298 by 73
# shape of graphlet for chromosome 18 of cell all:                 298 by 73
# shape of graphlet for chromosome 18 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr18_orbit00.paired.csv
# data/chr18_orbit01.paired.csv
# data/chr18_orbit02.paired.csv
# data/chr18_orbit03.paired.csv
# data/chr18_orbit04.paired.csv
# data/chr18_orbit05.paired.csv
# data/chr18_orbit06.paired.csv
# data/chr18_orbit07.paired.csv
# data/chr18_orbit08.paired.csv
# data/chr18_orbit09.paired.csv
# data/chr18_orbit10.paired.csv
# data/chr18_orbit11.paired.csv
# data/chr18_orbit12.paired.csv
# data/chr18_orbit13.paired.csv
# data/chr18_orbit14.paired.csv
# data/chr18_orbit15.paired.csv
# data/chr18_orbit16.paired.csv
# data/chr18_orbit17.paired.csv
# data/chr18_orbit18.paired.csv
# data/chr18_orbit19.paired.csv
# data/chr18_orbit20.paired.csv
# data/chr18_orbit21.paired.csv
# data/chr18_orbit22.paired.csv
# data/chr18_orbit23.paired.csv
# data/chr18_orbit24.paired.csv
# data/chr18_orbit25.paired.csv
# data/chr18_orbit26.paired.csv
# data/chr18_orbit27.paired.csv
# data/chr18_orbit28.paired.csv
# data/chr18_orbit29.paired.csv
# data/chr18_orbit30.paired.csv
# data/chr18_orbit31.paired.csv
# data/chr18_orbit32.paired.csv
# data/chr18_orbit33.paired.csv
# data/chr18_orbit34.paired.csv
# data/chr18_orbit35.paired.csv
# data/chr18_orbit36.paired.csv
# data/chr18_orbit37.paired.csv
# data/chr18_orbit38.paired.csv
# data/chr18_orbit39.paired.csv
# data/chr18_orbit40.paired.csv
# data/chr18_orbit41.paired.csv
# data/chr18_orbit42.paired.csv
# data/chr18_orbit43.paired.csv
# data/chr18_orbit44.paired.csv
# data/chr18_orbit45.paired.csv
# data/chr18_orbit46.paired.csv
# data/chr18_orbit47.paired.csv
# data/chr18_orbit48.paired.csv
# data/chr18_orbit49.paired.csv
# data/chr18_orbit50.paired.csv
# data/chr18_orbit51.paired.csv
# data/chr18_orbit52.paired.csv
# data/chr18_orbit53.paired.csv
# data/chr18_orbit54.paired.csv
# data/chr18_orbit55.paired.csv
# data/chr18_orbit56.paired.csv
# data/chr18_orbit57.paired.csv
# data/chr18_orbit58.paired.csv
# data/chr18_orbit59.paired.csv
# data/chr18_orbit60.paired.csv
# data/chr18_orbit61.paired.csv
# data/chr18_orbit62.paired.csv
# data/chr18_orbit63.paired.csv
# data/chr18_orbit64.paired.csv
# data/chr18_orbit65.paired.csv
# data/chr18_orbit66.paired.csv
# data/chr18_orbit67.paired.csv
# data/chr18_orbit68.paired.csv
# data/chr18_orbit69.paired.csv
# data/chr18_orbit70.paired.csv
# data/chr18_orbit71.paired.csv
# data/chr18_orbit72.paired.csv
# shape of graphlet for chromosome 19 of cell rl:                 298 by 73
# shape of graphlet for chromosome 19 of cell call4:                 298 by 73
# shape of graphlet for chromosome 19 of cell all:                 298 by 73
# shape of graphlet for chromosome 19 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr19_orbit00.paired.csv
# data/chr19_orbit01.paired.csv
# data/chr19_orbit02.paired.csv
# data/chr19_orbit03.paired.csv
# data/chr19_orbit04.paired.csv
# data/chr19_orbit05.paired.csv
# data/chr19_orbit06.paired.csv
# data/chr19_orbit07.paired.csv
# data/chr19_orbit08.paired.csv
# data/chr19_orbit09.paired.csv
# data/chr19_orbit10.paired.csv
# data/chr19_orbit11.paired.csv
# data/chr19_orbit12.paired.csv
# data/chr19_orbit13.paired.csv
# data/chr19_orbit14.paired.csv
# data/chr19_orbit15.paired.csv
# data/chr19_orbit16.paired.csv
# data/chr19_orbit17.paired.csv
# data/chr19_orbit18.paired.csv
# data/chr19_orbit19.paired.csv
# data/chr19_orbit20.paired.csv
# data/chr19_orbit21.paired.csv
# data/chr19_orbit22.paired.csv
# data/chr19_orbit23.paired.csv
# data/chr19_orbit24.paired.csv
# data/chr19_orbit25.paired.csv
# data/chr19_orbit26.paired.csv
# data/chr19_orbit27.paired.csv
# data/chr19_orbit28.paired.csv
# data/chr19_orbit29.paired.csv
# data/chr19_orbit30.paired.csv
# data/chr19_orbit31.paired.csv
# data/chr19_orbit32.paired.csv
# data/chr19_orbit33.paired.csv
# data/chr19_orbit34.paired.csv
# data/chr19_orbit35.paired.csv
# data/chr19_orbit36.paired.csv
# data/chr19_orbit37.paired.csv
# data/chr19_orbit38.paired.csv
# data/chr19_orbit39.paired.csv
# data/chr19_orbit40.paired.csv
# data/chr19_orbit41.paired.csv
# data/chr19_orbit42.paired.csv
# data/chr19_orbit43.paired.csv
# data/chr19_orbit44.paired.csv
# data/chr19_orbit45.paired.csv
# data/chr19_orbit46.paired.csv
# data/chr19_orbit47.paired.csv
# data/chr19_orbit48.paired.csv
# data/chr19_orbit49.paired.csv
# data/chr19_orbit50.paired.csv
# data/chr19_orbit51.paired.csv
# data/chr19_orbit52.paired.csv
# data/chr19_orbit53.paired.csv
# data/chr19_orbit54.paired.csv
# data/chr19_orbit55.paired.csv
# data/chr19_orbit56.paired.csv
# data/chr19_orbit57.paired.csv
# data/chr19_orbit58.paired.csv
# data/chr19_orbit59.paired.csv
# data/chr19_orbit60.paired.csv
# data/chr19_orbit61.paired.csv
# data/chr19_orbit62.paired.csv
# data/chr19_orbit63.paired.csv
# data/chr19_orbit64.paired.csv
# data/chr19_orbit65.paired.csv
# data/chr19_orbit66.paired.csv
# data/chr19_orbit67.paired.csv
# data/chr19_orbit68.paired.csv
# data/chr19_orbit69.paired.csv
# data/chr19_orbit70.paired.csv
# data/chr19_orbit71.paired.csv
# data/chr19_orbit72.paired.csv
# shape of graphlet for chromosome 20 of cell rl:                 298 by 73
# shape of graphlet for chromosome 20 of cell call4:                 298 by 73
# shape of graphlet for chromosome 20 of cell all:                 298 by 73
# shape of graphlet for chromosome 20 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr20_orbit00.paired.csv
# data/chr20_orbit01.paired.csv
# data/chr20_orbit02.paired.csv
# data/chr20_orbit03.paired.csv
# data/chr20_orbit04.paired.csv
# data/chr20_orbit05.paired.csv
# data/chr20_orbit06.paired.csv
# data/chr20_orbit07.paired.csv
# data/chr20_orbit08.paired.csv
# data/chr20_orbit09.paired.csv
# data/chr20_orbit10.paired.csv
# data/chr20_orbit11.paired.csv
# data/chr20_orbit12.paired.csv
# data/chr20_orbit13.paired.csv
# data/chr20_orbit14.paired.csv
# data/chr20_orbit15.paired.csv
# data/chr20_orbit16.paired.csv
# data/chr20_orbit17.paired.csv
# data/chr20_orbit18.paired.csv
# data/chr20_orbit19.paired.csv
# data/chr20_orbit20.paired.csv
# data/chr20_orbit21.paired.csv
# data/chr20_orbit22.paired.csv
# data/chr20_orbit23.paired.csv
# data/chr20_orbit24.paired.csv
# data/chr20_orbit25.paired.csv
# data/chr20_orbit26.paired.csv
# data/chr20_orbit27.paired.csv
# data/chr20_orbit28.paired.csv
# data/chr20_orbit29.paired.csv
# data/chr20_orbit30.paired.csv
# data/chr20_orbit31.paired.csv
# data/chr20_orbit32.paired.csv
# data/chr20_orbit33.paired.csv
# data/chr20_orbit34.paired.csv
# data/chr20_orbit35.paired.csv
# data/chr20_orbit36.paired.csv
# data/chr20_orbit37.paired.csv
# data/chr20_orbit38.paired.csv
# data/chr20_orbit39.paired.csv
# data/chr20_orbit40.paired.csv
# data/chr20_orbit41.paired.csv
# data/chr20_orbit42.paired.csv
# data/chr20_orbit43.paired.csv
# data/chr20_orbit44.paired.csv
# data/chr20_orbit45.paired.csv
# data/chr20_orbit46.paired.csv
# data/chr20_orbit47.paired.csv
# data/chr20_orbit48.paired.csv
# data/chr20_orbit49.paired.csv
# data/chr20_orbit50.paired.csv
# data/chr20_orbit51.paired.csv
# data/chr20_orbit52.paired.csv
# data/chr20_orbit53.paired.csv
# data/chr20_orbit54.paired.csv
# data/chr20_orbit55.paired.csv
# data/chr20_orbit56.paired.csv
# data/chr20_orbit57.paired.csv
# data/chr20_orbit58.paired.csv
# data/chr20_orbit59.paired.csv
# data/chr20_orbit60.paired.csv
# data/chr20_orbit61.paired.csv
# data/chr20_orbit62.paired.csv
# data/chr20_orbit63.paired.csv
# data/chr20_orbit64.paired.csv
# data/chr20_orbit65.paired.csv
# data/chr20_orbit66.paired.csv
# data/chr20_orbit67.paired.csv
# data/chr20_orbit68.paired.csv
# data/chr20_orbit69.paired.csv
# data/chr20_orbit70.paired.csv
# data/chr20_orbit71.paired.csv
# data/chr20_orbit72.paired.csv
# shape of graphlet for chromosome 21 of cell rl:                 298 by 73
# shape of graphlet for chromosome 21 of cell call4:                 298 by 73
# shape of graphlet for chromosome 21 of cell all:                 298 by 73
# shape of graphlet for chromosome 21 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr21_orbit00.paired.csv
# data/chr21_orbit01.paired.csv
# data/chr21_orbit02.paired.csv
# data/chr21_orbit03.paired.csv
# data/chr21_orbit04.paired.csv
# data/chr21_orbit05.paired.csv
# data/chr21_orbit06.paired.csv
# data/chr21_orbit07.paired.csv
# data/chr21_orbit08.paired.csv
# data/chr21_orbit09.paired.csv
# data/chr21_orbit10.paired.csv
# data/chr21_orbit11.paired.csv
# data/chr21_orbit12.paired.csv
# data/chr21_orbit13.paired.csv
# data/chr21_orbit14.paired.csv
# data/chr21_orbit15.paired.csv
# data/chr21_orbit16.paired.csv
# data/chr21_orbit17.paired.csv
# data/chr21_orbit18.paired.csv
# data/chr21_orbit19.paired.csv
# data/chr21_orbit20.paired.csv
# data/chr21_orbit21.paired.csv
# data/chr21_orbit22.paired.csv
# data/chr21_orbit23.paired.csv
# data/chr21_orbit24.paired.csv
# data/chr21_orbit25.paired.csv
# data/chr21_orbit26.paired.csv
# data/chr21_orbit27.paired.csv
# data/chr21_orbit28.paired.csv
# data/chr21_orbit29.paired.csv
# data/chr21_orbit30.paired.csv
# data/chr21_orbit31.paired.csv
# data/chr21_orbit32.paired.csv
# data/chr21_orbit33.paired.csv
# data/chr21_orbit34.paired.csv
# data/chr21_orbit35.paired.csv
# data/chr21_orbit36.paired.csv
# data/chr21_orbit37.paired.csv
# data/chr21_orbit38.paired.csv
# data/chr21_orbit39.paired.csv
# data/chr21_orbit40.paired.csv
# data/chr21_orbit41.paired.csv
# data/chr21_orbit42.paired.csv
# data/chr21_orbit43.paired.csv
# data/chr21_orbit44.paired.csv
# data/chr21_orbit45.paired.csv
# data/chr21_orbit46.paired.csv
# data/chr21_orbit47.paired.csv
# data/chr21_orbit48.paired.csv
# data/chr21_orbit49.paired.csv
# data/chr21_orbit50.paired.csv
# data/chr21_orbit51.paired.csv
# data/chr21_orbit52.paired.csv
# data/chr21_orbit53.paired.csv
# data/chr21_orbit54.paired.csv
# data/chr21_orbit55.paired.csv
# data/chr21_orbit56.paired.csv
# data/chr21_orbit57.paired.csv
# data/chr21_orbit58.paired.csv
# data/chr21_orbit59.paired.csv
# data/chr21_orbit60.paired.csv
# data/chr21_orbit61.paired.csv
# data/chr21_orbit62.paired.csv
# data/chr21_orbit63.paired.csv
# data/chr21_orbit64.paired.csv
# data/chr21_orbit65.paired.csv
# data/chr21_orbit66.paired.csv
# data/chr21_orbit67.paired.csv
# data/chr21_orbit68.paired.csv
# data/chr21_orbit69.paired.csv
# data/chr21_orbit70.paired.csv
# data/chr21_orbit71.paired.csv
# data/chr21_orbit72.paired.csv
# shape of graphlet for chromosome 22 of cell rl:                 298 by 73
# shape of graphlet for chromosome 22 of cell call4:                 298 by 73
# shape of graphlet for chromosome 22 of cell all:                 298 by 73
# shape of graphlet for chromosome 22 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr22_orbit00.paired.csv
# data/chr22_orbit01.paired.csv
# data/chr22_orbit02.paired.csv
# data/chr22_orbit03.paired.csv
# data/chr22_orbit04.paired.csv
# data/chr22_orbit05.paired.csv
# data/chr22_orbit06.paired.csv
# data/chr22_orbit07.paired.csv
# data/chr22_orbit08.paired.csv
# data/chr22_orbit09.paired.csv
# data/chr22_orbit10.paired.csv
# data/chr22_orbit11.paired.csv
# data/chr22_orbit12.paired.csv
# data/chr22_orbit13.paired.csv
# data/chr22_orbit14.paired.csv
# data/chr22_orbit15.paired.csv
# data/chr22_orbit16.paired.csv
# data/chr22_orbit17.paired.csv
# data/chr22_orbit18.paired.csv
# data/chr22_orbit19.paired.csv
# data/chr22_orbit20.paired.csv
# data/chr22_orbit21.paired.csv
# data/chr22_orbit22.paired.csv
# data/chr22_orbit23.paired.csv
# data/chr22_orbit24.paired.csv
# data/chr22_orbit25.paired.csv
# data/chr22_orbit26.paired.csv
# data/chr22_orbit27.paired.csv
# data/chr22_orbit28.paired.csv
# data/chr22_orbit29.paired.csv
# data/chr22_orbit30.paired.csv
# data/chr22_orbit31.paired.csv
# data/chr22_orbit32.paired.csv
# data/chr22_orbit33.paired.csv
# data/chr22_orbit34.paired.csv
# data/chr22_orbit35.paired.csv
# data/chr22_orbit36.paired.csv
# data/chr22_orbit37.paired.csv
# data/chr22_orbit38.paired.csv
# data/chr22_orbit39.paired.csv
# data/chr22_orbit40.paired.csv
# data/chr22_orbit41.paired.csv
# data/chr22_orbit42.paired.csv
# data/chr22_orbit43.paired.csv
# data/chr22_orbit44.paired.csv
# data/chr22_orbit45.paired.csv
# data/chr22_orbit46.paired.csv
# data/chr22_orbit47.paired.csv
# data/chr22_orbit48.paired.csv
# data/chr22_orbit49.paired.csv
# data/chr22_orbit50.paired.csv
# data/chr22_orbit51.paired.csv
# data/chr22_orbit52.paired.csv
# data/chr22_orbit53.paired.csv
# data/chr22_orbit54.paired.csv
# data/chr22_orbit55.paired.csv
# data/chr22_orbit56.paired.csv
# data/chr22_orbit57.paired.csv
# data/chr22_orbit58.paired.csv
# data/chr22_orbit59.paired.csv
# data/chr22_orbit60.paired.csv
# data/chr22_orbit61.paired.csv
# data/chr22_orbit62.paired.csv
# data/chr22_orbit63.paired.csv
# data/chr22_orbit64.paired.csv
# data/chr22_orbit65.paired.csv
# data/chr22_orbit66.paired.csv
# data/chr22_orbit67.paired.csv
# data/chr22_orbit68.paired.csv
# data/chr22_orbit69.paired.csv
# data/chr22_orbit70.paired.csv
# data/chr22_orbit71.paired.csv
# data/chr22_orbit72.paired.csv
# shape of graphlet for chromosome 23 of cell rl:                 298 by 73
# shape of graphlet for chromosome 23 of cell call4:                 298 by 73
# shape of graphlet for chromosome 23 of cell all:                 298 by 73
# shape of graphlet for chromosome 23 of cell mit:                 298 by 73
# ('number of matrices:', 4)
# data/chr23_orbit00.paired.csv
# data/chr23_orbit01.paired.csv
# data/chr23_orbit02.paired.csv
# data/chr23_orbit03.paired.csv
# data/chr23_orbit04.paired.csv
# data/chr23_orbit05.paired.csv
# data/chr23_orbit06.paired.csv
# data/chr23_orbit07.paired.csv
# data/chr23_orbit08.paired.csv
# data/chr23_orbit09.paired.csv
# data/chr23_orbit10.paired.csv
# data/chr23_orbit11.paired.csv
# data/chr23_orbit12.paired.csv
# data/chr23_orbit13.paired.csv
# data/chr23_orbit14.paired.csv
# data/chr23_orbit15.paired.csv
# data/chr23_orbit16.paired.csv
# data/chr23_orbit17.paired.csv
# data/chr23_orbit18.paired.csv
# data/chr23_orbit19.paired.csv
# data/chr23_orbit20.paired.csv
# data/chr23_orbit21.paired.csv
# data/chr23_orbit22.paired.csv
# data/chr23_orbit23.paired.csv
# data/chr23_orbit24.paired.csv
# data/chr23_orbit25.paired.csv
# data/chr23_orbit26.paired.csv
# data/chr23_orbit27.paired.csv
# data/chr23_orbit28.paired.csv
# data/chr23_orbit29.paired.csv
# data/chr23_orbit30.paired.csv
# data/chr23_orbit31.paired.csv
# data/chr23_orbit32.paired.csv
# data/chr23_orbit33.paired.csv
# data/chr23_orbit34.paired.csv
# data/chr23_orbit35.paired.csv
# data/chr23_orbit36.paired.csv
# data/chr23_orbit37.paired.csv
# data/chr23_orbit38.paired.csv
# data/chr23_orbit39.paired.csv
# data/chr23_orbit40.paired.csv
# data/chr23_orbit41.paired.csv
# data/chr23_orbit42.paired.csv
# data/chr23_orbit43.paired.csv
# data/chr23_orbit44.paired.csv
# data/chr23_orbit45.paired.csv
# data/chr23_orbit46.paired.csv
# data/chr23_orbit47.paired.csv
# data/chr23_orbit48.paired.csv
# data/chr23_orbit49.paired.csv
# data/chr23_orbit50.paired.csv
# data/chr23_orbit51.paired.csv
# data/chr23_orbit52.paired.csv
# data/chr23_orbit53.paired.csv
# data/chr23_orbit54.paired.csv
# data/chr23_orbit55.paired.csv
# data/chr23_orbit56.paired.csv
# data/chr23_orbit57.paired.csv
# data/chr23_orbit58.paired.csv
# data/chr23_orbit59.paired.csv
# data/chr23_orbit60.paired.csv
# data/chr23_orbit61.paired.csv
# data/chr23_orbit62.paired.csv
# data/chr23_orbit63.paired.csv
# data/chr23_orbit64.paired.csv
# data/chr23_orbit65.paired.csv
# data/chr23_orbit66.paired.csv
# data/chr23_orbit67.paired.csv
# data/chr23_orbit68.paired.csv
# data/chr23_orbit69.paired.csv
# data/chr23_orbit70.paired.csv
# data/chr23_orbit71.paired.csv
# data/chr23_orbit72.paired.csv

# %%
for chr1 in range(2, 24):
    for orbit in range(73):
        file_name = "data/chr%02d_orbit%02d.paired.csv"%(chr1, orbit)
        command = "java -jar mine.jar %s -allPairs"%file_name
        os.system(command)

# %%
pairwise_hic = {}
for key in graphlets:
    pairwise_hic = {}
    for key in graphlets:
        pairwise_hic[key] = {}
for orbit in range(73):
    var1, var2, mic = get_mic_from_file\
        ("data/chr%02d_orbit%02d.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"\
         %(chr1, orbit))
    n = len(var1)
    for i in range(n):
        pairwise_hic[var1[i]][var2[i]] = mic[i]
        pairwise_hic[var2[i]][var1[i]] = mic[i]
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-23-c6c8d65ff2e0> in <module>()
#       5         pairwise_hic[key] = {}
#       6 for orbit in range(73):
# ----> 7     var1, var2, mic = get_mic_from_file        ("data/chr%02d_orbit%02d.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"         %(chr1, orbit))
#       8     n = len(var1)
#       9     for i in range(n):
#
# /home/bzr0014/watson/scripts/utility.pyc in get_mic_from_file(file_name, delimiter)
#     455 def get_mic_from_file(file_name, delimiter=','):
#     456     #print(file_name)
# --> 457     file = open(file_name)
#     458     line = [x for x in file.readline().split(delimiter)]
#     459     #print(line)
#
# IOError: [Errno 2] No such file or directory: 'data/chr23_orbit00.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv'

# %%
pairwise_hic
# Out:
# {'all': {'call4': 0.19763, 'mit': 0.07124, 'rl': 0.19249},
#  'call4': {'all': 0.19763, 'mit': 0.13637, 'rl': 0.21876},
#  'mit': {'all': 0.07124, 'call4': 0.13637, 'rl': 0.15893},
#  'rl': {'all': 0.19249, 'call4': 0.21876, 'mit': 0.15893}}

# %%
pairwise_hic_chr = [[], [], []]
for chr1 in range(1, 23):
    if chr1 == 19 or chr1 == 22:
        continue
    pairwise_hic = {}
    for key in graphlets:
        pairwise_hic = {}
        for key in graphlets:
            pairwise_hic[key] = {}
    for orbit in range(73):
        var1, var2, mic = get_mic_from_file\
            ("data/chr%02d_orbit%02d.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"\
             %(chr1, orbit))
        n = len(var1)
        for i in range(n):
            pairwise_hic[var1[i]][var2[i]] = mic[i]
            pairwise_hic[var2[i]][var1[i]] = mic[i]
        pairwise_hic_chr[0].append(pairwise_hic['mit']['all'])
        pairwise_hic_chr[1].append(pairwise_hic['mit']['rl'])
        pairwise_hic_chr[2].append(pairwise_hic['mit']['call4'])
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-21-0fc1cd4ae846> in <module>()
#       9             pairwise_hic[key] = {}
#      10     for orbit in range(73):
# ---> 11         var1, var2, mic = get_mic_from_file            ("data/chr%02d_orbit%02d.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv"             %(chr1, orbit))
#      12         n = len(var1)
#      13         for i in range(n):
#
# /home/bzr0014/watson/scripts/utility.pyc in get_mic_from_file(file_name, delimiter)
#     455 def get_mic_from_file(file_name, delimiter=','):
#     456     #print(file_name)
# --> 457     file = open(file_name)
#     458     line = [x for x in file.readline().split(delimiter)]
#     459     #print(line)
#
# IOError: [Errno 2] No such file or directory: 'data/chr02_orbit00.paired.csv,allpairs,cv=0.0,B=n^0.6,Results.csv'

# %%
pylab.rcParams['figure.figsize'] = (15, 9)
mat_all = np.array(pairwise_hic_chr[0]).reshape(-1, 73)
mat_rl = np.array(pairwise_hic_chr[1]).reshape(-1, 73)
mat_call4 = np.array(pairwise_hic_chr[2]).reshape(-1, 73)

x = range(mat_all.shape[0])
ax = plt.subplot(1, 1, 1)
vsAll, = ax.plot(range(20), np.mean(mat_all, axis=1), marker="o")
vsRl, = ax.plot(range(20), np.mean(mat_rl, axis=1), marker="o")
vsCall4, = ax.plot(range(20), np.mean(mat_call4, axis=1), marker="o")
plt.show()
(mat_all.shape)
# Out:
# (20, 73)

# %%
pylab.rcParams['figure.figsize'] = (15, 5)
mat_all = np.array(pairwise_hic_chr[0]).reshape(-1, 73)
mat_rl = np.array(pairwise_hic_chr[1]).reshape(-1, 73)
mat_call4 = np.array(pairwise_hic_chr[2]).reshape(-1, 73)
x = range(mat_all.shape[0])

ax = plt.subplot(1, 1, 1)
vsAll, = ax.plot(range(73), np.mean(mat_all, axis=0), marker="o")
vsRl, = ax.plot(range(73), np.mean(mat_rl, axis=0), marker="o")
vsCall4, = ax.plot(range(73), np.mean(mat_call4, axis=0), marker="o")
plt.show()
(mat_all.shape)
# Out:
# (20, 73)

# %%
pylab.rcParams['figure.figsize'] = (15, 12)
mat_all = np.array(pairwise_hic_chr[0]).reshape(20, 73)
mat_rl = np.array(pairwise_hic_chr[1]).reshape(20, 73)
mat_call4 = np.array(pairwise_hic_chr[2]).reshape(20, 73)
x = range(mat_all.shape[1])

y = np.mean(mat_all, axis=0)
y_error = np.std(mat_all, axis=0)
ax = plt.subplot(3, 1, 1)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")


y = np.mean(mat_rl, axis=0)
y_error = np.std(mat_rl, axis=0)
ax = plt.subplot(3, 1, 2)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")
#vsCall4, = ax.plot(range(73), np.mean(mat_call4, axis=0))

y = np.mean(mat_call4, axis=0)
y_error = np.std(mat_call4, axis=0)
ax = plt.subplot(3, 1, 3)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")
plt.show()
(mat_all.shape)
# Out:
# (20, 73)

# %%
pylab.rcParams['figure.figsize'] = (15, 12)
distances_mean = {'mit-all':[], 'mit-rl':[], 'mit-call4':[]}
distances_std = {'mit-all':[], 'mit-rl':[], 'mit-call4':[]}
for chr1 in range(1, 24):
    graphlets_mit = readMat("data/chr%02d_chr%02d_mit.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
    graphlets_all = readMat("data/chr%02d_chr%02d_all.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
    graphlets_rl = readMat("data/chr%02d_chr%02d_rl.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
    graphlets_call4 = readMat("data/chr%02d_chr%02d_call4.graphlets"%(chr1, chr1), delimiter=" ").astype('uint32')
    distances_mean['mit-all'].append(graphlet_distance(graphlets_mit, graphlets_all).mean())
    distances_mean['mit-rl'].append(graphlet_distance(graphlets_mit, graphlets_rl).mean())
    distances_mean['mit-call4'].append(graphlet_distance(graphlets_mit, graphlets_call4).mean())
    distances_std['mit-all'].append(graphlet_distance(graphlets_mit, graphlets_all).std())
    distances_std['mit-rl'].append(graphlet_distance(graphlets_mit, graphlets_rl).std())
    distances_std['mit-call4'].append(graphlet_distance(graphlets_mit, graphlets_call4).std())
print distances_std
x = range(23)
y = distances_mean
y_error = distances_std 
ax = plt.subplot(3, 1, 1)
vsAll, = ax.plot(x, y, linestyle="dashed", marker="o", color="green")
ax.errorbar(x, y, yerr=y_error, linestyle="dashed", marker="None", color="green")
plt.show()
# Out:
# file directory: data/chr01_chr01_mit.graphlets
# file directory: data/chr01_chr01_all.graphlets
# file directory: data/chr01_chr01_rl.graphlets
# file directory: data/chr01_chr01_call4.graphlets
# file directory: data/chr02_chr02_mit.graphlets
# file directory: data/chr02_chr02_all.graphlets
# file directory: data/chr02_chr02_rl.graphlets
# file directory: data/chr02_chr02_call4.graphlets
# file directory: data/chr03_chr03_mit.graphlets
# file directory: data/chr03_chr03_all.graphlets
# file directory: data/chr03_chr03_rl.graphlets
# file directory: data/chr03_chr03_call4.graphlets
# file directory: data/chr04_chr04_mit.graphlets
# file directory: data/chr04_chr04_all.graphlets
# file directory: data/chr04_chr04_rl.graphlets
# file directory: data/chr04_chr04_call4.graphlets
# file directory: data/chr05_chr05_mit.graphlets
# file directory: data/chr05_chr05_all.graphlets
# file directory: data/chr05_chr05_rl.graphlets
# file directory: data/chr05_chr05_call4.graphlets
# file directory: data/chr06_chr06_mit.graphlets
# file directory: data/chr06_chr06_all.graphlets
# file directory: data/chr06_chr06_rl.graphlets
# file directory: data/chr06_chr06_call4.graphlets
# file directory: data/chr07_chr07_mit.graphlets
# file directory: data/chr07_chr07_all.graphlets
# file directory: data/chr07_chr07_rl.graphlets
# file directory: data/chr07_chr07_call4.graphlets
# file directory: data/chr08_chr08_mit.graphlets
# file directory: data/chr08_chr08_all.graphlets
# file directory: data/chr08_chr08_rl.graphlets
# file directory: data/chr08_chr08_call4.graphlets
# file directory: data/chr09_chr09_mit.graphlets
# file directory: data/chr09_chr09_all.graphlets
# file directory: data/chr09_chr09_rl.graphlets
# file directory: data/chr09_chr09_call4.graphlets
# file directory: data/chr10_chr10_mit.graphlets
# file directory: data/chr10_chr10_all.graphlets
# file directory: data/chr10_chr10_rl.graphlets
# file directory: data/chr10_chr10_call4.graphlets
# file directory: data/chr11_chr11_mit.graphlets
# file directory: data/chr11_chr11_all.graphlets
# file directory: data/chr11_chr11_rl.graphlets
# file directory: data/chr11_chr11_call4.graphlets
# file directory: data/chr12_chr12_mit.graphlets
# file directory: data/chr12_chr12_all.graphlets
# file directory: data/chr12_chr12_rl.graphlets
# file directory: data/chr12_chr12_call4.graphlets
# file directory: data/chr13_chr13_mit.graphlets
# file directory: data/chr13_chr13_all.graphlets
# file directory: data/chr13_chr13_rl.graphlets
# file directory: data/chr13_chr13_call4.graphlets
# file directory: data/chr14_chr14_mit.graphlets
# file directory: data/chr14_chr14_all.graphlets
# file directory: data/chr14_chr14_rl.graphlets
# file directory: data/chr14_chr14_call4.graphlets
# file directory: data/chr15_chr15_mit.graphlets
# file directory: data/chr15_chr15_all.graphlets
# file directory: data/chr15_chr15_rl.graphlets
# file directory: data/chr15_chr15_call4.graphlets
# file directory: data/chr16_chr16_mit.graphlets
# file directory: data/chr16_chr16_all.graphlets
# file directory: data/chr16_chr16_rl.graphlets
# file directory: data/chr16_chr16_call4.graphlets
# file directory: data/chr17_chr17_mit.graphlets
# file directory: data/chr17_chr17_all.graphlets
# file directory: data/chr17_chr17_rl.graphlets
# file directory: data/chr17_chr17_call4.graphlets
# file directory: data/chr18_chr18_mit.graphlets
# file directory: data/chr18_chr18_all.graphlets
# file directory: data/chr18_chr18_rl.graphlets
# file directory: data/chr18_chr18_call4.graphlets
# file directory: data/chr19_chr19_mit.graphlets
# file directory: data/chr19_chr19_all.graphlets
# file directory: data/chr19_chr19_rl.graphlets
# file directory: data/chr19_chr19_call4.graphlets
# file directory: data/chr20_chr20_mit.graphlets
# file directory: data/chr20_chr20_all.graphlets
# file directory: data/chr20_chr20_rl.graphlets
# file directory: data/chr20_chr20_call4.graphlets
# file directory: data/chr21_chr21_mit.graphlets
# file directory: data/chr21_chr21_all.graphlets
# file directory: data/chr21_chr21_rl.graphlets
# file directory: data/chr21_chr21_call4.graphlets
# file directory: data/chr22_chr22_mit.graphlets
# file directory: data/chr22_chr22_all.graphlets
# file directory: data/chr22_chr22_rl.graphlets
# file directory: data/chr22_chr22_call4.graphlets
# file directory: data/chr23_chr23_mit.graphlets
# file directory: data/chr23_chr23_all.graphlets
# file directory: data/chr23_chr23_rl.graphlets
# file directory: data/chr23_chr23_call4.graphlets
# [0.23063557121622624, 0.16869316392848285, 0.17414251694965127, 0.2063520628974781, 0.23313811088962597, 0.28941240961884224, 0.23046420929182834, 0.24137754132949285, 0.41481492617067905, 0.3408972673313287, 0.2953442744085218, 0.4323129695265058, 0.7620562173377974, 0.4152524325031355, 0.3570427055832496, 0.5060897060178738, 0.6325936921630981, 0.4358771071482756, 0.5095358867469647, 0.5441331964104478, 0.4628809532610191, 0.5214190300444581, 0.20985110682055502]
