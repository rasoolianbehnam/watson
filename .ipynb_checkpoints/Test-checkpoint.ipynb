# %%
import numpy as np
import tensorflow as tf
from utility import *
import matplotlib.pyplot as plt
from matplotlib import colors
import os
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# /home/bzr0014/anaconda3/envs/tensorCpu/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Populating the interactive namespace from numpy and matplotlib
# /home/bzr0014/anaconda3/envs/tensorCpu/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['colors', 'log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
root = "./"
nss_low = np.load("%s/length_low_res.npy"%root)
nss_high = np.load("%s/length_high_res.npy"%root)
mit_low = np.load("%s/mit_low_res.npy"%root)
mit_high = np.load("%s/mit_high_res.npy"%root)
#mit_low = np.log(mit_low + 1)
#mit_high = np.log(mit_high + 1)
mit_low = (mit_low - mit_low.mean()) / mit_low.std()
mit_high = (mit_high - mit_high.mean()) / mit_high.std()

# %%
chr1 = 19
chr2 = 19
halfSize = 11
for chr1 in range(1, 24):
    for chr2 in range(chr1, chr1+1):
#        begLowRow = nss_low[chr1, 0]
#        begLowCol = nss_low[chr2, 0]
#        begHighRow = nss_high[chr1, 0]
#        begHighCol = nss_high[chr2, 0]
#        n = np.min([nss_low[chr1, 1], nss_high[chr1, 1]])
#        m = np.min([nss_low[chr2, 1], nss_high[chr2, 1]])
#        pylab.rcParams['figure.figsize'] = (15, 20)
        lowConMap = extractContactMapFromLargeMatrix(mit_low, nss_low, chr1, chr2)
        highConMap = extractContactMapFromLargeMatrix(mit_high, nss_high, chr1, chr2)
        lowConMap, highConMap = cropToSameSize(lowConMap, highConMap) 
        Xout, yOut = extractNeighborhood(lowConMap, highConMap, halfSize=halfSize)
        print(yOut.shape)
        images = [lowConMap, highConMap, Xout[:, :, 11, 11, 0], yOut[:, :]]
        showImages(images)
# Out:
# Cropping to mininmum size ...
# n = 495 ; m = 495
# (473, 473, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 486
# (473, 464, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 396
# (473, 374, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 383
# (473, 361, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 362
# (473, 340, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 342
# (473, 320, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 318
# (473, 296, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 293
# (473, 271, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 281
# (473, 259, 1)
# Number of rows and columns: 1, 4
# Cropping to mininmum size ...
# n = 495 ; m = 271
# (473, 249, 1)
# ...

# %%
Xout, yOut = extractNeighborhood(origin=mit_low[:220, :310], target=mit_high[:220, :310], halfSize=11, cropToMin=True)
print(Xout.shape)
print(yOut.shape)
# Out:
# Cropping to mininmum size ...
# n = 220 ; m = 310
# (198, 288, 23, 23, 1)
# (198, 288)

# %%
XXX, YYY, cache = loadData()
# Out:
# Starting to load data...
# Cropping to mininmum size ...
# n = 495 ; m = 495
# Cropping to mininmum size ...
# n = 486 ; m = 486
# Cropping to mininmum size ...
# n = 396 ; m = 396
# Cropping to mininmum size ...
# n = 383 ; m = 383
# Cropping to mininmum size ...
# n = 362 ; m = 362
# Cropping to mininmum size ...
# n = 342 ; m = 342
# Cropping to mininmum size ...
# n = 318 ; m = 318
# Cropping to mininmum size ...
# n = 293 ; m = 293
# Cropping to mininmum size ...
# n = 281 ; m = 281
# Cropping to mininmum size ...
# n = 271 ; m = 271
# Cropping to mininmum size ...
# n = 269 ; m = 269
# Cropping to mininmum size ...
# n = 265 ; m = 265
# Cropping to mininmum size ...
# n = 229 ; m = 229
# Cropping to mininmum size ...
# n = 213 ; m = 213
# Cropping to mininmum size ...
# n = 201 ; m = 201
# Cropping to mininmum size ...
# n = 178 ; m = 178
# Cropping to mininmum size ...
# n = 158 ; m = 158
# Cropping to mininmum size ...
# n = 153 ; m = 153
# Cropping to mininmum size ...
# ...

# %%
print((XXX).shape)
print((YYY).shape)
print(len(cache))
print(cache[2])
# Out:
# (1623013, 23, 23, 1)
# (1623013,)
# 1623013
# (1, 1, 11, 13)

# %%
nss_low.shape
# Out:
# (24, 2)

# %%
chr1 = [2]
chr2 = [3]
images = {}
nLow = nss_low[chr1, 1]
mLow = nss_low[chr2, 1]
nHigh = nss_high[chr1, 1]
mHigh = nss_high[chr2, 1]
n = np.min([nLow, nHigh])
m = np.min([mLow, mHigh])
reconstructed_low = np.zeros((n, m))
reconstructed_high = np.zeros((n, m))
for i in range(len(cache)):
    if c1 not in chr1 and c2 not in chr2:
        continue
    c1, c2, x, y = cache[i]
    reconstructed_low[x, y] = XXX[i, 11, 11, 0]
    reconstructed_high[x, y] = YYY[i]

# %%
pylab.rcParams['figure.figsize'] = (15, 20)
images = [reconstructed_low, reconstructed_high, reconstructed_high-reconstructed_low]
showImages(images)
# Out:
# Number of rows and columns: 1, 3
