# %%
import numpy as np
import cv2
from iced import filter
from iced import normalization
from utility import *
import matplotlib.pyplot as plt
from matplotlib import colors
from iced import normalization
from iced import filter
from scipy.stats import t
import os
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /home/bzr0014/watson/scripts/virt/local/lib/python2.7/site-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['colors', 'log']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
data_names = {"MIT", "ALL", "RL", "call4"}

# %%
file_dir_template = "../data/extracted_all_contact_%s"
file_name_template = "%s/all_in_one_500kb.mat"%(file_dir_template)
print(file_dir_template)
print(file_name_template)
# Out:
# ../data/extracted_all_contact_%s
# ../data/extracted_all_contact_%s/all_in_one_500kb.mat

# %%
for key in data:
    data[key] = readMat(file_name_template%key, delimiter=',').astype('uint32')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-236fc4a41b72> in <module>()
#       1 for key in data:
# ----> 2     data[key] = readMat(file_name_template%key, delimiter=',').astype('uint32')
#
# /home/bzr0014/watson/scripts/utility.py in readMat(fileName, delimiter, ignoreHeader, remove_blanks)
#      89         for i in range(0, len(strings)):
#      90             num = strings[i]
# ---> 91             lineNums.append(float(num))
#      92         x.append(lineNums)
#      93     observed = np.array(x).astype("float")
#
# KeyboardInterrupt:

# %%
lengths = dict.fromkeys(data.keys(),[])
for key in lengths:
    lengths[key] = readMat("%s/lengths_500kb.mat"%(file_dir_template%key), delimiter=',').astype('uint32')

# %%
pylab.rcParams['figure.figsize'] = (15, 12)
images = []
for key in data:
    images.append(data[key])
showImages(images, 2)
# Out:
# Number of columnts: 2

# %%
normed = dict.fromkeys(data.keys(),[])

# %%
for key in normed:
    normed[key] = filter.filter_low_counts(data[key], lengths=lengths[key][:, 1], percentage=.04)
    normed[key] = normalization.ICE_normalization(normed[key])

# %%
pylab.rcParams['figure.figsize'] = (15, 12)
images = []
for key in normed:
    images.append(data[key])
showImages(images, 2)
# Out:
# Number of columnts: 2

# %%
normed = dict.fromkeys(data.keys(),[])

# %%
data_name = 'MIT'
n = lengths[data_name][1, 1]
b, u, sig, v = svd_reconstruct(removeBlankRowsAndColumns(data[data_name][:n, :n],)[0], 430)
images = [ b ]
showImages(images, 1, color_bar=True)
# Out:
# blonk rows: [281, 280, 279, 278, 277, 276, 275, 274, 273, 272, 271, 270, 269, 268, 267, 266, 265, 264, 263, 262, 261, 260, 259, 258, 257, 256, 255, 254, 253, 252, 251, 250, 249, 248, 247, 246, 245, 244, 243, 0]
# size of new matrix: (455, 455)
# calculating u, sig and v ...
# finished with svd, commencing reconstruction ...
# Number of columnts: 1
